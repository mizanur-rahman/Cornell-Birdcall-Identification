# %% [markdown]
# # Birdsong Pytorch Baseline: ResNeSt50-fast (Training)

# %% [markdown]
# ### import libraries

# %%
# %%bash
# pip install ../input/pytorch-pfn-extras/pytorch-pfn-extras-0.2.1/
# Out:
# Processing /kaggle/input/pytorch-pfn-extras/pytorch-pfn-extras-0.2.1
# Requirement already satisfied: numpy in /opt/conda/lib/python3.7/site-packages (from pytorch-pfn-extras==0.2.1) (1.18.1)
# Requirement already satisfied: torch in /opt/conda/lib/python3.7/site-packages (from pytorch-pfn-extras==0.2.1) (1.5.0)
# Requirement already satisfied: future in /opt/conda/lib/python3.7/site-packages (from torch->pytorch-pfn-extras==0.2.1) (0.18.2)
# Building wheels for collected packages: pytorch-pfn-extras
#   Building wheel for pytorch-pfn-extras (setup.py): started
#   Building wheel for pytorch-pfn-extras (setup.py): finished with status 'done'
#   Created wheel for pytorch-pfn-extras: filename=pytorch_pfn_extras-0.2.1-py3-none-any.whl size=61392 sha256=50aaa51c9936893b0854558a2352a79dff84e2061b0ad43aca98d51771435481
#   Stored in directory: /root/.cache/pip/wheels/4b/6d/96/1a021d23511ce1a377638f67ba1b0d8d1832fbcd3f0c6c1442
# Successfully built pytorch-pfn-extras
# Installing collected packages: pytorch-pfn-extras
# Successfully installed pytorch-pfn-extras-0.2.1
# WARNING: You are using pip version 20.1.1; however, version 20.2.2 is available.
# You should consider upgrading via the '/opt/conda/bin/python3.7 -m pip install --upgrade pip' command.

# %%
"""%%bash
pip install ../input/resnest50-fast-package/resnest-0.0.6b20200701/resnest/"""
# Out:
# '%%bash\npip install ../input/resnest50-fast-package/resnest-0.0.6b20200701/resnest/'

# %%
#!pip install audiomentations
# !pip install timm
# Out:
# Collecting timm
#   Downloading timm-0.2.1-py3-none-any.whl (225 kB)
#      |████████████████████████████████| 225 kB 547 kB/s
# Requirement already satisfied: torch>=1.4 in /opt/conda/lib/python3.7/site-packages (from timm) (1.5.0)
# Requirement already satisfied: torchvision in /opt/conda/lib/python3.7/site-packages (from timm) (0.6.0a0+82fd1c8)
# Requirement already satisfied: future in /opt/conda/lib/python3.7/site-packages (from torch>=1.4->timm) (0.18.2)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.7/site-packages (from torch>=1.4->timm) (1.18.1)
# Requirement already satisfied: pillow>=4.1.1 in /opt/conda/lib/python3.7/site-packages (from torchvision->timm) (5.4.1)
# Installing collected packages: timm
# Successfully installed timm-0.2.1
# WARNING: You are using pip version 20.1.1; however, version 20.2.2 is available.
# You should consider upgrading via the '/opt/conda/bin/python3.7 -m pip install --upgrade pip' command.

# %%
import os
import gc
import time
import shutil
import random
import warnings
import typing as tp
from pathlib import Path
from contextlib import contextmanager
from tqdm import tqdm, tqdm_notebook
import yaml
from joblib import delayed, Parallel
import timm
import cv2
import librosa
import audioread
import soundfile as sf

import numpy as np
import pandas as pd

from sklearn.metrics import f1_score
from sklearn.model_selection import StratifiedKFold

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.utils.data as data
#import resnest.torch as resnest_torch
from tqdm.notebook import tqdm
import pytorch_pfn_extras as ppe
from pytorch_pfn_extras.training import extensions as ppe_extensions
import albumentations

pd.options.display.max_rows = 500
pd.options.display.max_columns = 500

# %%
Path("/root/.cache/torch/checkpoints").mkdir(parents=True)

# %%
# !cp ../input/resnest50-fast-package/resnest50_fast_*.pth /root/.cache/torch/checkpoints/

# %% [markdown]
# ### define utilities

# %%
def set_seed(seed: int = 42):
    random.seed(seed)
    np.random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)  # type: ignore
#     torch.backends.cudnn.deterministic = True  # type: ignore
#     torch.backends.cudnn.benchmark = True  # type: ignore
    

@contextmanager
def timer(name: str) -> None:
    """Timer Util"""
    t0 = time.time()
    print("[{}] start".format(name))
    yield
    print("[{}] done in {:.0f} s".format(name, time.time() - t0))

# %% [markdown]
# ### read data

# %%
ROOT = Path.cwd().parent
INPUT_ROOT = ROOT / "input"
RAW_DATA = INPUT_ROOT / "birdsong-recognition"
TRAIN_AUDIO_DIR = RAW_DATA / "train_audio"
TRAIN_RESAMPLED_AUDIO_DIRS = [
  INPUT_ROOT / "birdsong-resampled-train-audio-{:0>2}".format(i)  for i in range(5)
]
TEST_AUDIO_DIR = RAW_DATA / "test_audio"

# %%
# train = pd.read_csv(RAW_DATA / "train.csv")
train = pd.read_csv(TRAIN_RESAMPLED_AUDIO_DIRS[0] / "train_mod.csv")

# %%
train.head().T
# Out:
#                                                                          0  \
# rating                                                                 3.5
# playback_used                                                           no
# ebird_code                                                          aldfly
# channels                                                          1 (mono)
# date                                                            2013-05-25
# pitch                                                        Not specified
# duration                                                                25
# filename                                                      XC134874.mp3
# speed                                                        Not specified
# species                                                   Alder Flycatcher
# number_of_notes                                              Not specified
# title                        XC134874 Alder Flycatcher (Empidonax alnorum)
# secondary_labels         ['Empidonax minimus_Least Flycatcher', 'Leioth...
# bird_seen                                                              yes
# sci_name                                                 Empidonax alnorum
# location                       Grey Cloud Dunes SNA, Washington, Minnesota
# latitude                                                            44.793
# sampling_rate                                                   48000 (Hz)
# type                                                                  call
# elevation                                                            220 m
# description              Two short segments of fairly quiet *pip* calls...
# bitrate_of_mp3                                                192000 (bps)
# file_type                                                              mp3
# volume                                                       Not specified
# background               American Yellow Warbler (Setophaga aestiva); L...
# xc_id                                                               134874
# url                                      https://www.xeno-canto.org/134874
# country                                                      United States
# author                                                    Jonathon Jongsma
# primary_label                           Empidonax alnorum_Alder Flycatcher
# longitude                                                          -92.962
# length                                                       Not specified
# time                                                                  8:00
# recordist                                                 Jonathon Jongsma
# license                        Creative Commons Attribution-ShareAlike 3.0
# resampled_sampling_rate                                              32000
# resampled_filename                                            XC134874.wav
# resampled_channels                                                1 (mono)
#
#                                                                          1  \
# rating                                                                   4
# playback_used                                                           no
# ebird_code                                                          aldfly
# channels                                                        2 (stereo)
# date                                                            2013-05-27
# pitch                                                                 both
# duration                                                                36
# filename                                                      XC135454.mp3
# speed                                                                 both
# species                                                   Alder Flycatcher
# number_of_notes                                                        1-3
# title                        XC135454 Alder Flycatcher (Empidonax alnorum)
# secondary_labels                                                        []
# bird_seen                                                              yes
# sci_name                                                 Empidonax alnorum
# location                  Carver's Gap Parking area, Roan Mountain Stat...
# latitude                                                           36.1065
# sampling_rate                                                   44100 (Hz)
# type                                                            call, song
# elevation                                                           1700 m
# description              At least three birds seen here moving around s...
# bitrate_of_mp3                                                128000 (bps)
# file_type                                                              mp3
# volume                                                               level
# background                                                             NaN
# xc_id                                                               135454
# url                                      https://www.xeno-canto.org/135454
# country                                                      United States
# author                                                         Mike Nelson
# primary_label                           Empidonax alnorum_Alder Flycatcher
# longitude                                                         -82.1106
# length                                                              0-3(s)
# time                                                                 08:30
# recordist                                                      Mike Nelson
# license                  Creative Commons Attribution-NonCommercial-Sha...
# resampled_sampling_rate                                              32000
# resampled_filename                                            XC135454.wav
# resampled_channels                                                1 (mono)
#
#                                                                          2  \
# rating                                                                   4
# playback_used                                                           no
# ebird_code                                                          aldfly
# channels                                                        2 (stereo)
# date                                                            2013-05-27
# pitch                                                                 both
# duration                                                                39
# filename                                                      XC135455.mp3
# speed                                                                 both
# species                                                   Alder Flycatcher
# number_of_notes                                                        1-3
# title                        XC135455 Alder Flycatcher (Empidonax alnorum)
# secondary_labels                                                        []
# bird_seen                                                              yes
# sci_name                                                 Empidonax alnorum
# location                  Carver's Gap Parking area, Roan Mountain Stat...
# latitude                                                           36.1065
# sampling_rate                                                   44100 (Hz)
# type                                                            call, song
# elevation                                                           1700 m
# description              At least three birds seen chasing each other a...
# bitrate_of_mp3                                                128000 (bps)
# file_type                                                              mp3
# volume                                                               level
# background                                                             NaN
# xc_id                                                               135455
# url                                      https://www.xeno-canto.org/135455
# country                                                      United States
# author                                                         Mike Nelson
# primary_label                           Empidonax alnorum_Alder Flycatcher
# longitude                                                         -82.1106
# length                                                              0-3(s)
# time                                                                 08:30
# recordist                                                      Mike Nelson
# license                  Creative Commons Attribution-NonCommercial-Sha...
# resampled_sampling_rate                                              32000
# resampled_filename                                            XC135455.wav
# resampled_channels                                                1 (mono)
#
#                                                                          3  \
# rating                                                                 3.5
# playback_used                                                           no
# ebird_code                                                          aldfly
# channels                                                        2 (stereo)
# date                                                            2013-05-27
# pitch                                                                 both
# duration                                                                33
# filename                                                      XC135456.mp3
# speed                                                                 both
# species                                                   Alder Flycatcher
# number_of_notes                                                        1-3
# title                        XC135456 Alder Flycatcher (Empidonax alnorum)
# secondary_labels         ['Dumetella carolinensis_Gray Catbird', 'Bomby...
# bird_seen                                                              yes
# sci_name                                                 Empidonax alnorum
# location                  Carver's Gap Parking area, Roan Mountain Stat...
# latitude                                                           36.1065
# sampling_rate                                                   44100 (Hz)
# type                                                            call, song
# elevation                                                           1700 m
# description              img:http://www.flickr.com/photos/madbirder/888...
# bitrate_of_mp3                                                128000 (bps)
# file_type                                                              mp3
# volume                                                               level
# background               Grey Catbird (Dumetella carolinensis); Cedar W...
# xc_id                                                               135456
# url                                      https://www.xeno-canto.org/135456
# country                                                      United States
# author                                                         Mike Nelson
# primary_label                           Empidonax alnorum_Alder Flycatcher
# longitude                                                         -82.1106
# length                                                              0-3(s)
# time                                                                 08:30
# recordist                                                      Mike Nelson
# license                  Creative Commons Attribution-NonCommercial-Sha...
# resampled_sampling_rate                                              32000
# resampled_filename                                            XC135456.wav
# resampled_channels                                                1 (mono)
#
#                                                                          4
# rating                                                                   4
# playback_used                                                           no
# ebird_code                                                          aldfly
# channels                                                        2 (stereo)
# date                                                            2013-05-27
# pitch                                                                 both
# duration                                                                36
# filename                                                      XC135457.mp3
# speed                                                                level
# species                                                   Alder Flycatcher
# number_of_notes                                                        1-3
# title                        XC135457 Alder Flycatcher (Empidonax alnorum)
# secondary_labels                                                        []
# bird_seen                                                              yes
# sci_name                                                 Empidonax alnorum
# location                  Carver's Gap Parking area, Roan Mountain Stat...
# latitude                                                           36.1065
# sampling_rate                                                   44100 (Hz)
# type                                                            call, song
# elevation                                                           1700 m
# description              img:http://www.flickr.com/photos/madbirder/888...
# bitrate_of_mp3                                                128000 (bps)
# file_type                                                              mp3
# volume                                                               level
# background                                                             NaN
# xc_id                                                               135457
# url                                      https://www.xeno-canto.org/135457
# country                                                      United States
# author                                                         Mike Nelson
# primary_label                           Empidonax alnorum_Alder Flycatcher
# longitude                                                         -82.1106
# length                                                              0-3(s)
# time                                                                 08:30
# recordist                                                      Mike Nelson
# license                  Creative Commons Attribution-NonCommercial-Sha...
# resampled_sampling_rate                                              32000
# resampled_filename                                            XC135457.wav
# resampled_channels                                                1 (mono)

# %%
if not TEST_AUDIO_DIR.exists():
    TEST_AUDIO_DIR = INPUT_ROOT / "birdcall-check" / "test_audio"
    test = pd.read_csv(INPUT_ROOT / "birdcall-check" / "test.csv")
else:
    test = pd.read_csv(RAW_DATA / "test.csv")

# %%
test.head().T
# Out:
#                                                   0  \
# site                                         site_1
# row_id    site_1_41e6fe6504a34bf6846938ba78d13df1_5
# seconds                                           5
# audio_id           41e6fe6504a34bf6846938ba78d13df1
#
#                                                    1  \
# site                                          site_1
# row_id    site_1_41e6fe6504a34bf6846938ba78d13df1_10
# seconds                                           10
# audio_id            41e6fe6504a34bf6846938ba78d13df1
#
#                                                    2  \
# site                                          site_1
# row_id    site_1_41e6fe6504a34bf6846938ba78d13df1_15
# seconds                                           15
# audio_id            41e6fe6504a34bf6846938ba78d13df1
#
#                                                    3  \
# site                                          site_1
# row_id    site_1_41e6fe6504a34bf6846938ba78d13df1_20
# seconds                                           20
# audio_id            41e6fe6504a34bf6846938ba78d13df1
#
#                                                    4
# site                                          site_1
# row_id    site_1_41e6fe6504a34bf6846938ba78d13df1_25
# seconds                                           25
# audio_id            41e6fe6504a34bf6846938ba78d13df1

# %% [markdown]
# ### settings

# %%
settings_str = """
globals:
  seed: 1213
  device: cuda
  num_epochs: 45
  output_dir: /kaggle/training_output/
  use_fold: 2
  target_sr: 32000

dataset:
  name: SpectrogramDataset
  params:
    img_size: 224
    melspectrogram_parameters:
      n_mels: 128
      fmin: 20
      fmax: 16000
    
split:
  name: StratifiedKFold
  params:
    n_splits: 5
    random_state: 42
    shuffle: True

loader:
  train:
    batch_size: 50
    shuffle: True
    num_workers: 2
    pin_memory: True
    drop_last: True
  val:
    batch_size: 100
    shuffle: False
    num_workers: 2
    pin_memory: True
    drop_last: False

model:
  params:
    pretrained: True
    n_classes: 264

loss:
  name: BCEWithLogitsLoss
  params: {}

optimizer:
  name: Adam
  params:
    lr: 0.001

scheduler:
  name: CosineAnnealingLR
  params:
    T_max: 10
"""

# %%
settings = yaml.safe_load(settings_str)

# %%
#if not torch.cuda.is_available():
#    settings["globals"]["device"] = "cpu"

# %%
for k, v in settings.items():
    print("[{}]".format(k))
    print(v)
# Out:
# [globals]
# {'seed': 1213, 'device': 'cuda', 'num_epochs': 45, 'output_dir': '/kaggle/training_output/', 'use_fold': 2, 'target_sr': 32000}
# [dataset]
# {'name': 'SpectrogramDataset', 'params': {'img_size': 224, 'melspectrogram_parameters': {'n_mels': 128, 'fmin': 20, 'fmax': 16000}}}
# [split]
# {'name': 'StratifiedKFold', 'params': {'n_splits': 5, 'random_state': 42, 'shuffle': True}}
# [loader]
# {'train': {'batch_size': 50, 'shuffle': True, 'num_workers': 2, 'pin_memory': True, 'drop_last': True}, 'val': {'batch_size': 100, 'shuffle': False, 'num_workers': 2, 'pin_memory': True, 'drop_last': False}}
# [model]
# {'params': {'pretrained': True, 'n_classes': 264}}
# [loss]
# {'name': 'BCEWithLogitsLoss', 'params': {}}
# [optimizer]
# {'name': 'Adam', 'params': {'lr': 0.001}}
# [scheduler]
# {'name': 'CosineAnnealingLR', 'params': {'T_max': 10}}

# %% [markdown]
# ### preprocess audio data
#
# Code is forked from: https://github.com/koukyo1994/kaggle-birdcall-resnet-baseline-training/blob/master/input/birdsong-recognition/prepare.py
#
# I modified this partially.
#
# However, in this notebook, I used uploaded resampled audio because this preprocessing is too heavy for kaggle notebook.

# %%
def resample(ebird_code: str,filename: str, target_sr: int):    
    audio_dir = TRAIN_AUDIO_DIR
    resample_dir = TRAIN_RESAMPLED_DIR
    ebird_dir = resample_dir / ebird_code
    
    try:
        y, _ = librosa.load(
            audio_dir / ebird_code / filename,
            sr=target_sr, mono=True, res_type="kaiser_fast")

        filename = filename.replace(".mp3", ".wav")
        sf.write(ebird_dir / filename, y, samplerate=target_sr)
    except Exception as e:
        print(e)
        with open("skipped.txt", "a") as f:
            file_path = str(audio_dir / ebird_code / filename)
            f.write(file_path + "\n")

# %% [markdown]
# ## Definition

# %% [markdown]
# ### Dataset
# * forked from: https://github.com/koukyo1994/kaggle-birdcall-resnet-baseline-training/blob/master/src/dataset.py
# * modified partialy

# %%
BIRD_CODE = {
    'aldfly': 0, 'ameavo': 1, 'amebit': 2, 'amecro': 3, 'amegfi': 4,
    'amekes': 5, 'amepip': 6, 'amered': 7, 'amerob': 8, 'amewig': 9,
    'amewoo': 10, 'amtspa': 11, 'annhum': 12, 'astfly': 13, 'baisan': 14,
    'baleag': 15, 'balori': 16, 'banswa': 17, 'barswa': 18, 'bawwar': 19,
    'belkin1': 20, 'belspa2': 21, 'bewwre': 22, 'bkbcuc': 23, 'bkbmag1': 24,
    'bkbwar': 25, 'bkcchi': 26, 'bkchum': 27, 'bkhgro': 28, 'bkpwar': 29,
    'bktspa': 30, 'blkpho': 31, 'blugrb1': 32, 'blujay': 33, 'bnhcow': 34,
    'boboli': 35, 'bongul': 36, 'brdowl': 37, 'brebla': 38, 'brespa': 39,
    'brncre': 40, 'brnthr': 41, 'brthum': 42, 'brwhaw': 43, 'btbwar': 44,
    'btnwar': 45, 'btywar': 46, 'buffle': 47, 'buggna': 48, 'buhvir': 49,
    'bulori': 50, 'bushti': 51, 'buwtea': 52, 'buwwar': 53, 'cacwre': 54,
    'calgul': 55, 'calqua': 56, 'camwar': 57, 'cangoo': 58, 'canwar': 59,
    'canwre': 60, 'carwre': 61, 'casfin': 62, 'caster1': 63, 'casvir': 64,
    'cedwax': 65, 'chispa': 66, 'chiswi': 67, 'chswar': 68, 'chukar': 69,
    'clanut': 70, 'cliswa': 71, 'comgol': 72, 'comgra': 73, 'comloo': 74,
    'commer': 75, 'comnig': 76, 'comrav': 77, 'comred': 78, 'comter': 79,
    'comyel': 80, 'coohaw': 81, 'coshum': 82, 'cowscj1': 83, 'daejun': 84,
    'doccor': 85, 'dowwoo': 86, 'dusfly': 87, 'eargre': 88, 'easblu': 89,
    'easkin': 90, 'easmea': 91, 'easpho': 92, 'eastow': 93, 'eawpew': 94,
    'eucdov': 95, 'eursta': 96, 'evegro': 97, 'fiespa': 98, 'fiscro': 99,
    'foxspa': 100, 'gadwal': 101, 'gcrfin': 102, 'gnttow': 103, 'gnwtea': 104,
    'gockin': 105, 'gocspa': 106, 'goleag': 107, 'grbher3': 108, 'grcfly': 109,
    'greegr': 110, 'greroa': 111, 'greyel': 112, 'grhowl': 113, 'grnher': 114,
    'grtgra': 115, 'grycat': 116, 'gryfly': 117, 'haiwoo': 118, 'hamfly': 119,
    'hergul': 120, 'herthr': 121, 'hoomer': 122, 'hoowar': 123, 'horgre': 124,
    'horlar': 125, 'houfin': 126, 'houspa': 127, 'houwre': 128, 'indbun': 129,
    'juntit1': 130, 'killde': 131, 'labwoo': 132, 'larspa': 133, 'lazbun': 134,
    'leabit': 135, 'leafly': 136, 'leasan': 137, 'lecthr': 138, 'lesgol': 139,
    'lesnig': 140, 'lesyel': 141, 'lewwoo': 142, 'linspa': 143, 'lobcur': 144,
    'lobdow': 145, 'logshr': 146, 'lotduc': 147, 'louwat': 148, 'macwar': 149,
    'magwar': 150, 'mallar3': 151, 'marwre': 152, 'merlin': 153, 'moublu': 154,
    'mouchi': 155, 'moudov': 156, 'norcar': 157, 'norfli': 158, 'norhar2': 159,
    'normoc': 160, 'norpar': 161, 'norpin': 162, 'norsho': 163, 'norwat': 164,
    'nrwswa': 165, 'nutwoo': 166, 'olsfly': 167, 'orcwar': 168, 'osprey': 169,
    'ovenbi1': 170, 'palwar': 171, 'pasfly': 172, 'pecsan': 173, 'perfal': 174,
    'phaino': 175, 'pibgre': 176, 'pilwoo': 177, 'pingro': 178, 'pinjay': 179,
    'pinsis': 180, 'pinwar': 181, 'plsvir': 182, 'prawar': 183, 'purfin': 184,
    'pygnut': 185, 'rebmer': 186, 'rebnut': 187, 'rebsap': 188, 'rebwoo': 189,
    'redcro': 190, 'redhea': 191, 'reevir1': 192, 'renpha': 193, 'reshaw': 194,
    'rethaw': 195, 'rewbla': 196, 'ribgul': 197, 'rinduc': 198, 'robgro': 199,
    'rocpig': 200, 'rocwre': 201, 'rthhum': 202, 'ruckin': 203, 'rudduc': 204,
    'rufgro': 205, 'rufhum': 206, 'rusbla': 207, 'sagspa1': 208, 'sagthr': 209,
    'savspa': 210, 'saypho': 211, 'scatan': 212, 'scoori': 213, 'semplo': 214,
    'semsan': 215, 'sheowl': 216, 'shshaw': 217, 'snobun': 218, 'snogoo': 219,
    'solsan': 220, 'sonspa': 221, 'sora': 222, 'sposan': 223, 'spotow': 224,
    'stejay': 225, 'swahaw': 226, 'swaspa': 227, 'swathr': 228, 'treswa': 229,
    'truswa': 230, 'tuftit': 231, 'tunswa': 232, 'veery': 233, 'vesspa': 234,
    'vigswa': 235, 'warvir': 236, 'wesblu': 237, 'wesgre': 238, 'weskin': 239,
    'wesmea': 240, 'wessan': 241, 'westan': 242, 'wewpew': 243, 'whbnut': 244,
    'whcspa': 245, 'whfibi': 246, 'whtspa': 247, 'whtswi': 248, 'wilfly': 249,
    'wilsni1': 250, 'wiltur': 251, 'winwre3': 252, 'wlswar': 253, 'wooduc': 254,
    'wooscj2': 255, 'woothr': 256, 'y00475': 257, 'yebfly': 258, 'yebsap': 259,
    'yehbla': 260, 'yelwar': 261, 'yerwar': 262, 'yetvir': 263
}

INV_BIRD_CODE = {v: k for k, v in BIRD_CODE.items()}

# %%
PERIOD = 5

def mono_to_color(
    X: np.ndarray, mean=None, std=None,
    norm_max=None, norm_min=None, eps=1e-6
):
    # Stack X as [X,X,X]
    X = np.stack([X, X, X], axis=-1)

    # Standardize
    mean = mean or X.mean()
    X = X - mean
    std = std or X.std()
    Xstd = X / (std + eps)
    _min, _max = Xstd.min(), Xstd.max()
    norm_max = norm_max or _max
    norm_min = norm_min or _min
    if (_max - _min) > eps:
        # Normalize to [0, 255]
        V = Xstd
        V[V < norm_min] = norm_min
        V[V > norm_max] = norm_max
        V = 255 * (V - norm_min) / (norm_max - norm_min)
        V = V.astype(np.uint8)
    else:
        # Just zero
        V = np.zeros_like(Xstd, dtype=np.uint8)
    return V

class SpectrogramDataset(data.Dataset):
    def __init__(
        self,
        file_list: tp.List[tp.List[str]], img_size=224,
        waveform_transforms=None, spectrogram_transforms=None, melspectrogram_parameters={}
    ):
        self.file_list = file_list  # list of list: [file_path, ebird_code]
        self.img_size = img_size
        self.waveform_transforms = waveform_transforms
        self.spectrogram_transforms = spectrogram_transforms
        self.melspectrogram_parameters = melspectrogram_parameters

    def __len__(self):
        return len(self.file_list)

    def __getitem__(self, idx: int):
        wav_path, ebird_code = self.file_list[idx]

        y, sr = sf.read(wav_path)

        if self.waveform_transforms is not None:
            y = self.waveform_transforms(y,sample_rate = sr)
        
        len_y = len(y)
        effective_length = sr * PERIOD
        if len_y < effective_length:
            new_y = np.zeros(effective_length, dtype=y.dtype)
            start = np.random.randint(effective_length - len_y)
            new_y[start:start + len_y] = y
            y = new_y.astype(np.float32)
        elif len_y > effective_length:
            start = np.random.randint(len_y - effective_length)
            y = y[start:start + effective_length].astype(np.float32)
        else:
            y = y.astype(np.float32)

        melspec = librosa.feature.melspectrogram(y, sr=sr, **self.melspectrogram_parameters)
        melspec = librosa.power_to_db(melspec).astype(np.float32)

        if self.spectrogram_transforms:
            melspec = self.spectrogram_transforms(melspec)
        else:
            pass

        image = mono_to_color(melspec)
        height, width, _ = image.shape
        #image = cv2.resize(image, (int(547), self.img_size))
        image = cv2.resize(image, (int(width * self.img_size / height), self.img_size))
        image = np.moveaxis(image, 2, 0)
        image = (image / 255.0).astype(np.float32)
        #print(image.shape)
#         labels = np.zeros(len(BIRD_CODE), dtype="i")
        labels = np.zeros(len(BIRD_CODE), dtype="f")
        labels[BIRD_CODE[ebird_code]] = 1

        return image, labels

# %% [markdown]
# ### Training Utility

# %%
def get_loaders_for_training(
    args_dataset: tp.Dict, 
    args_loader: tp.Dict,
    train_file_list: tp.List[str], 
    val_file_list: tp.List[str]
):
    # # make dataset
    train_dataset = SpectrogramDataset(train_file_list,**args_dataset)
    val_dataset = SpectrogramDataset(val_file_list, **args_dataset)
    # # make dataloader
    train_loader = data.DataLoader(train_dataset, **args_loader["train"])
    val_loader = data.DataLoader(val_dataset, **args_loader["val"])
    
    return train_loader, val_loader

# %%
def get_model():
    model = timm.create_model('regnety_032',pretrained= True)
    #getattr(resnest_torch, args["name"])(pretrained=args["params"]["pretrained"])
    del model.head.fc
    # # use the same head as the baseline notebook.
    model.head.fc = nn.Sequential(
        nn.Linear(1512,1024), nn.ReLU(), nn.Dropout(p=0.2),
        nn.Linear(512*2, 512*2), nn.ReLU(), nn.Dropout(p=0.2),
        nn.Linear(512*2,264))
    
    return model

# %%
def train_loop(
    manager, args, model, device,
    train_loader, optimizer, scheduler, loss_func
):
    progress_bar = tqdm_notebook(train_loader)
    """Run minibatch training loop"""
    while not manager.stop_trigger:
        model.train()
        for batch_idx, (data, target) in enumerate(progress_bar):
            with manager.run_iteration():
                data, target = data.to(device), target.to(device)
                optimizer.zero_grad()
                output = model(data)
                loss = loss_func(output, target)
                ppe.reporting.report({'train/loss': loss.item()})
                loss.backward()
                optimizer.step()
                scheduler.step()

                
def eval_for_batch(
    args, model, device,
    data, target, loss_func, eval_func_dict={}
):
    """
    Run evaliation for valid
    
    This function is applied to each batch of val loader.
    """
    model.eval()
    data, target = data.to(device), target.to(device)
    output = model(data)
    # Final result will be average of averages of the same size
    val_loss = loss_func(output, target).item()
    ppe.reporting.report({'val/loss': val_loss})
    
    for eval_name, eval_func in eval_func_dict.items():
        eval_value = eval_func(output, target).item()
        ppe.reporting.report({"val/{}".format(eval_aame): eval_value})

# %%
def set_extensions(
    manager, args, model, device, test_loader, optimizer,
    loss_func, eval_func_dict={}
):
    """set extensions for PPE"""
        
    my_extensions = [
        # # observe, report
        ppe_extensions.observe_lr(optimizer=optimizer),
        # ppe_extensions.ParameterStatistics(model, prefix='model'),
        # ppe_extensions.VariableStatisticsPlot(model),
        ppe_extensions.LogReport(),
        ppe_extensions.PlotReport(['train/loss', 'val/loss'], 'epoch', filename='loss.png'),
        ppe_extensions.PlotReport(['lr',], 'epoch', filename='lr.png'),
        ppe_extensions.PrintReport([
            'epoch', 'iteration', 'lr', 'train/loss', 'val/loss', "elapsed_time"]),
#         ppe_extensions.ProgressBar(update_interval=100),

        # # evaluation
        (
            ppe_extensions.Evaluator(
                test_loader, model,
                eval_func=lambda data, target:
                    eval_for_batch(args, model, device, data, target, loss_func, eval_func_dict),
                progress_bar=True),
            (1, "epoch"),
        ),
        # # save model snapshot.
        (
            ppe_extensions.snapshot(
                target=model, filename="snapshot_epoch_{.updater.epoch}.pth"),
            ppe.training.triggers.MinValueTrigger(key="val/loss", trigger=(1, 'epoch'))
        ),
    ]
           
    # # set extensions to manager
    for ext in my_extensions:
        if isinstance(ext, tuple):
            manager.extend(ext[0], trigger=ext[1])
        else:
            manager.extend(ext)
        
    return manager

# %% [markdown]
# ## Training

# %% [markdown]
# ### prepare data

# %% [markdown]
# #### get wav file path

# %%
tmp_list = []
for audio_d in TRAIN_RESAMPLED_AUDIO_DIRS:
    if not audio_d.exists():
        continue
    for ebird_d in audio_d.iterdir():
        if ebird_d.is_file():
            continue
        for wav_f in ebird_d.iterdir():
            tmp_list.append([ebird_d.name, wav_f.name, wav_f.as_posix()])
            
train_wav_path_exist = pd.DataFrame(
    tmp_list, columns=["ebird_code", "resampled_filename", "file_path"])

del tmp_list

train_all = pd.merge(
    train, train_wav_path_exist, on=["ebird_code", "resampled_filename"], how="inner")

print(train.shape)
print(train_wav_path_exist.shape)
print(train_all.shape)
# Out:
# (21375, 38)
# (21375, 3)
# (21375, 39)

# %%
train_all.head()
# Out:
#    rating playback_used ebird_code    channels        date          pitch  \
# 0     3.5            no     aldfly    1 (mono)  2013-05-25  Not specified
# 1     4.0            no     aldfly  2 (stereo)  2013-05-27           both
# 2     4.0            no     aldfly  2 (stereo)  2013-05-27           both
# 3     3.5            no     aldfly  2 (stereo)  2013-05-27           both
# 4     4.0            no     aldfly  2 (stereo)  2013-05-27           both
#
#    duration      filename          speed           species number_of_notes  \
# 0        25  XC134874.mp3  Not specified  Alder Flycatcher   Not specified
# 1        36  XC135454.mp3           both  Alder Flycatcher             1-3
# 2        39  XC135455.mp3           both  Alder Flycatcher             1-3
# 3        33  XC135456.mp3           both  Alder Flycatcher             1-3
# 4        36  XC135457.mp3          level  Alder Flycatcher             1-3
#
#                                            title  \
# 0  XC134874 Alder Flycatcher (Empidonax alnorum)
# 1  XC135454 Alder Flycatcher (Empidonax alnorum)
# 2  XC135455 Alder Flycatcher (Empidonax alnorum)
# 3  XC135456 Alder Flycatcher (Empidonax alnorum)
# 4  XC135457 Alder Flycatcher (Empidonax alnorum)
#
#                                     secondary_labels bird_seen  \
# 0  ['Empidonax minimus_Least Flycatcher', 'Leioth...       yes
# 1                                                 []       yes
# 2                                                 []       yes
# 3  ['Dumetella carolinensis_Gray Catbird', 'Bomby...       yes
# 4                                                 []       yes
#
#             sci_name                                           location  \
# 0  Empidonax alnorum        Grey Cloud Dunes SNA, Washington, Minnesota
# 1  Empidonax alnorum   Carver's Gap Parking area, Roan Mountain Stat...
# 2  Empidonax alnorum   Carver's Gap Parking area, Roan Mountain Stat...
# 3  Empidonax alnorum   Carver's Gap Parking area, Roan Mountain Stat...
# 4  Empidonax alnorum   Carver's Gap Parking area, Roan Mountain Stat...
#
#   latitude sampling_rate        type elevation  \
# 0   44.793    48000 (Hz)        call     220 m
# 1  36.1065    44100 (Hz)  call, song    1700 m
# 2  36.1065    44100 (Hz)  call, song    1700 m
# 3  36.1065    44100 (Hz)  call, song    1700 m
# 4  36.1065    44100 (Hz)  call, song    1700 m
#
#                                          description bitrate_of_mp3 file_type  \
# 0  Two short segments of fairly quiet *pip* calls...   192000 (bps)       mp3
# 1  At least three birds seen here moving around s...   128000 (bps)       mp3
# 2  At least three birds seen chasing each other a...   128000 (bps)       mp3
# 3  img:http://www.flickr.com/photos/madbirder/888...   128000 (bps)       mp3
# 4  img:http://www.flickr.com/photos/madbirder/888...   128000 (bps)       mp3
#
#           volume                                         background   xc_id  \
# 0  Not specified  American Yellow Warbler (Setophaga aestiva); L...  134874
# 1          level                                                NaN  135454
# 2          level                                                NaN  135455
# 3          level  Grey Catbird (Dumetella carolinensis); Cedar W...  135456
# 4          level                                                NaN  135457
#
#                                  url        country            author  \
# 0  https://www.xeno-canto.org/134874  United States  Jonathon Jongsma
# 1  https://www.xeno-canto.org/135454  United States       Mike Nelson
# 2  https://www.xeno-canto.org/135455  United States       Mike Nelson
# 3  https://www.xeno-canto.org/135456  United States       Mike Nelson
# 4  https://www.xeno-canto.org/135457  United States       Mike Nelson
#
#                         primary_label longitude         length   time  \
# 0  Empidonax alnorum_Alder Flycatcher   -92.962  Not specified   8:00
# 1  Empidonax alnorum_Alder Flycatcher  -82.1106         0-3(s)  08:30
# 2  Empidonax alnorum_Alder Flycatcher  -82.1106         0-3(s)  08:30
# 3  Empidonax alnorum_Alder Flycatcher  -82.1106         0-3(s)  08:30
# 4  Empidonax alnorum_Alder Flycatcher  -82.1106         0-3(s)  08:30
#
#           recordist                                            license  \
# 0  Jonathon Jongsma        Creative Commons Attribution-ShareAlike 3.0
# 1       Mike Nelson  Creative Commons Attribution-NonCommercial-Sha...
# 2       Mike Nelson  Creative Commons Attribution-NonCommercial-Sha...
# 3       Mike Nelson  Creative Commons Attribution-NonCommercial-Sha...
# 4       Mike Nelson  Creative Commons Attribution-NonCommercial-Sha...
#
#    resampled_sampling_rate resampled_filename resampled_channels  \
# 0                    32000       XC134874.wav           1 (mono)
# 1                    32000       XC135454.wav           1 (mono)
# 2                    32000       XC135455.wav           1 (mono)
# 3                    32000       XC135456.wav           1 (mono)
# 4                    32000       XC135457.wav           1 (mono)
#
#                                            file_path
# 0  /kaggle/input/birdsong-resampled-train-audio-0...
# 1  /kaggle/input/birdsong-resampled-train-audio-0...
# 2  /kaggle/input/birdsong-resampled-train-audio-0...
# 3  /kaggle/input/birdsong-resampled-train-audio-0...
# 4  /kaggle/input/birdsong-resampled-train-audio-0...

# %% [markdown]
# #### split data

# %%
# # for test run
# test_run_idx = sorted(np.random.choice(len(train_all), len(train_all) // 10, replace=False))
# train_all = train_all.iloc[test_run_idx, :].reset_index(drop=True)
# settings["globals"]["num_epochs"] = 20
# settings["scheduler"]["params"]["T_max"] = 4

# %%
skf = StratifiedKFold(**settings["split"]["params"])

train_all["fold"] = -1
for fold_id, (train_index, val_index) in enumerate(skf.split(train_all, train_all["ebird_code"])):
    train_all.iloc[val_index, -1] = fold_id
    
# # check the propotion
fold_proportion = pd.pivot_table(train_all, index="ebird_code", columns="fold", values="xc_id", aggfunc=len)
print(fold_proportion.shape)
# Out:
# (264, 5)

# %%
fold_proportion
# Out:
# fold         0   1   2   3   4
# ebird_code
# aldfly      20  20  20  20  20
# ameavo       8   8   8   7   7
# amebit       9   9   8   9   9
# amecro      20  20  20  20  20
# amegfi      20  20  20  20  20
# amekes      15  15  15  15  15
# amepip      20  20  20  20  20
# amered      20  20  20  20  20
# amerob      20  20  20  20  20
# amewig       6   6   7   7   7
# amewoo      17  17  17  16  16
# amtspa      15  15  14  15  15
# annhum      20  20  20  20  20
# astfly      20  20  20  20  20
# baisan      11  11  11  11  11
# baleag       7   7   7   7   7
# balori      20  20  20  20  20
# banswa      20  20  20  20  20
# barswa      20  20  20  20  20
# bawwar      15  14  15  15  15
# belkin1     13  14  14  14  14
# belspa2     16  15  15  15  15
# bewwre      20  20  20  20  20
# bkbcuc       9  10  10  10   9
# bkbmag1     12  12  12  12  12
# bkbwar      20  20  20  20  20
# bkcchi      20  20  20  20  20
# bkchum      14  14  13  13  14
# bkhgro      20  20  20  20  20
# bkpwar      20  20  20  20  20
# bktspa      19  18  19  19  19
# blkpho      20  20  20  20  20
# blugrb1     20  20  20  20  20
# blujay      20  20  20  20  20
# bnhcow      20  20  20  20  20
# boboli      20  20  20  20  20
# bongul       8   8   8   8   8
# brdowl      20  20  20  20  20
# brebla       9  10  10  10  10
# brespa      20  20  20  20  20
# brncre      20  20  20  20  20
# brnthr      20  20  20  20  20
# brthum      20  20  20  20  19
# brwhaw      15  15  15  14  15
# btbwar      15  15  15  15  15
# btnwar      20  20  20  20  20
# btywar      19  19  19  20  19
# buffle       3   3   3   3   3
# buggna      20  20  20  20  20
# buhvir      20  20  20  20  20
# bulori      20  20  20  20  20
# bushti      20  20  20  20  20
# buwtea      11  11  10  10  11
# buwwar      19  19  20  20  19
# cacwre      20  20  20  20  20
# calgul       8   8   8   8   8
# calqua      18  18  18  18  18
# camwar      15  15  15  15  16
# cangoo      20  20  20  20  20
# canwar      20  20  20  20  20
# canwre      20  20  20  20  20
# carwre      20  20  20  20  20
# casfin      16  15  15  15  15
# caster1     20  20  20  20  20
# casvir      18  18  18  18  18
# cedwax      17  18  18  18  18
# chispa      20  20  20  20  20
# chiswi       6   6   6   6   5
# chswar      20  20  20  20  20
# chukar       6   6   6   6   6
# clanut      16  16  16  15  16
# cliswa      13  13  13  13  13
# comgol      17  17  17  18  18
# comgra      20  20  20  20  20
# comloo      14  13  13  13  13
# commer      16  17  17  16  16
# comnig      17  17  17  18  17
# comrav      20  20  20  20  20
# comred      20  20  20  20  20
# comter      20  20  20  20  20
# comyel      20  20  20  20  20
# coohaw      18  18  18  18  18
# coshum       4   4   4   3   4
# cowscj1     14  14  13  14  14
# daejun      20  20  20  20  20
# doccor       7   6   7   7   7
# dowwoo      20  20  20  20  20
# dusfly      19  20  20  20  19
# eargre       8   7   7   7   8
# easblu      19  20  19  19  19
# easkin      16  16  17  17  16
# easmea      20  20  20  20  20
# easpho      18  18  18  18  19
# eastow      20  20  20  20  20
# eawpew      20  20  20  20  20
# eucdov      20  20  20  20  20
# eursta       8   8   8   8   8
# evegro      20  20  20  20  20
# fiespa      20  20  20  20  20
# fiscro      18  18  17  17  17
# foxspa      20  20  20  20  20
# gadwal      20  20  20  20  20
# gcrfin       6   6   7   6   6
# gnttow      20  20  20  20  20
# gnwtea      20  20  20  20  20
# gockin      20  20  20  20  20
# gocspa      14  14  14  14  14
# goleag      10  10  10  10  10
# grbher3     14  14  14  15  15
# grcfly      20  20  20  20  20
# greegr      20  20  20  20  20
# greroa      18  18  18  18  18
# greyel      20  20  20  20  20
# grhowl      20  20  20  20  20
# grnher      14  13  13  13  13
# grtgra      20  20  20  20  20
# grycat      16  17  17  16  16
# gryfly      16  16  16  17  16
# haiwoo      20  20  20  20  20
# hamfly      20  20  20  20  20
# hergul      20  20  20  20  20
# herthr      20  20  20  20  20
# hoomer       4   4   4   3   4
# hoowar      20  20  20  20  20
# horgre      13  13  13  14  14
# horlar      20  20  20  20  20
# houfin      20  20  20  20  20
# houspa      20  20  20  20  20
# houwre      20  20  20  20  20
# indbun      20  20  20  20  20
# juntit1     14  14  14  14  13
# killde      20  20  20  20  20
# labwoo      17  17  17  17  17
# larspa      19  19  19  19  19
# lazbun      20  19  19  19  20
# leabit      18  19  18  18  18
# leafly      19  19  19  19  19
# leasan      15  14  15  15  15
# lecthr       4   4   4   4   4
# lesgol      20  20  20  20  20
# lesnig       8   9   9   8   8
# lesyel      20  20  20  20  20
# lewwoo       6   5   5   6   6
# linspa      20  20  20  20  20
# lobcur      13  14  13  13  13
# lobdow      15  15  15  15  15
# logshr      20  20  20  20  20
# lotduc      12  12  12  12  12
# louwat      20  20  20  20  20
# macwar      20  20  20  20  20
# magwar      20  20  20  20  20
# mallar3     20  20  20  20  20
# marwre      20  20  20  20  20
# merlin      11  11  12  12  11
# moublu       6   6   6   6   6
# mouchi      20  20  20  20  20
# moudov      20  20  20  20  20
# norcar      20  20  20  20  20
# norfli      20  20  20  20  20
# norhar2      6   6   6   5   6
# normoc      20  20  20  20  20
# norpar      20  20  20  20  20
# norpin       8   8   7   8   8
# norsho      13  13  13  13  13
# norwat      20  20  20  20  20
# nrwswa       6   6   6   6   6
# nutwoo       9   8   9   9   9
# olsfly      20  20  20  20  20
# orcwar      20  20  20  20  20
# osprey      20  20  20  20  20
# ovenbi1     20  20  20  20  20
# palwar       9  10   9   9   9
# pasfly      20  20  20  20  20
# pecsan      13  13  14  13  13
# perfal      20  20  20  20  20
# phaino      12  12  12  12  12
# pibgre      20  20  20  20  20
# pilwoo      20  20  20  20  20
# pingro      19  18  18  19  19
# pinjay      10  11  10  10  10
# pinsis      20  20  20  20  20
# pinwar      20  20  20  20  20
# plsvir      18  18  19  19  18
# prawar      14  14  14  14  14
# purfin      20  20  20  20  20
# pygnut      12  12  12  12  12
# rebmer       6   6   6   5   6
# rebnut      20  20  20  20  20
# rebsap       6   6   6   7   7
# rebwoo      20  20  20  20  20
# redcro      20  20  20  20  20
# redhea       2   2   2   2   1
# reevir1     20  20  20  20  20
# renpha      15  15  15  14  15
# reshaw      15  14  14  15  15
# rethaw      18  19  19  19  18
# rewbla      20  20  20  20  20
# ribgul      13  13  13  13  14
# rinduc       5   5   5   5   5
# robgro      20  20  20  20  20
# rocpig      20  20  20  20  20
# rocwre      16  16  16  15  15
# rthhum       6   6   6   7   6
# ruckin      20  20  20  20  20
# rudduc       5   5   4   4   5
# rufgro       5   4   5   5   5
# rufhum      11  12  12  12  12
# rusbla      12  12  11  11  11
# sagspa1      6   6   6   6   6
# sagthr       7   7   7   7   7
# savspa      20  20  20  20  20
# saypho      11  11  11  11  11
# scatan      19  18  19  19  19
# scoori      20  20  20  20  20
# semplo      12  13  13  13  13
# semsan      14  14  14  14  14
# sheowl      12  12  11  11  11
# shshaw       4   4   5   5   4
# snobun      20  20  20  20  20
# snogoo      16  15  15  15  16
# solsan      18  19  19  19  19
# sonspa      20  20  20  20  20
# sora        20  20  20  20  20
# sposan      19  19  19  18  18
# spotow      20  20  20  20  20
# stejay      20  20  20  20  20
# swahaw       5   5   5   6   5
# swaspa      20  20  20  20  20
# swathr      20  20  20  20  20
# treswa      17  17  17  17  17
# truswa       8   8   7   7   8
# tuftit      20  20  20  20  20
# tunswa      13  12  13  13  13
# veery       20  20  20  20  20
# vesspa      20  20  20  20  20
# vigswa      10  11  11  10  10
# warvir      20  20  20  20  20
# wesblu       7   7   7   7   7
# wesgre       8   7   7   8   8
# weskin      16  17  17  17  16
# wesmea      20  20  20  20  20
# wessan       6   6   6   6   6
# westan      20  20  20  20  20
# wewpew      20  20  20  20  20
# whbnut      20  20  20  20  20
# whcspa      20  20  20  20  20
# whfibi       7   7   6   6   7
# whtspa      20  20  20  20  20
# whtswi       7   7   8   7   7
# wilfly      20  20  20  20  20
# wilsni1     20  20  20  20  20
# wiltur       9   9   9  10   9
# winwre3     20  20  20  20  20
# wlswar      20  20  20  20  20
# wooduc       8   8   8   8   8
# wooscj2     18  18  18  17  18
# woothr      20  20  20  20  20
# y00475      20  20  20  20  20
# yebfly      20  20  20  20  20
# yebsap      13  12  12  13  13
# yehbla      11  12  12  11  11
# yelwar      18  18  17  18  18
# yerwar      20  20  20  20  20
# yetvir      19  19  20  20  20

# %%
use_fold = settings["globals"]["use_fold"]
train_file_list = train_all.query("fold != @use_fold")[["file_path", "ebird_code"]].values.tolist()
val_file_list = train_all.query("fold == @use_fold")[["file_path", "ebird_code"]].values.tolist()

print("[fold {}] train: {}, val: {}".format(use_fold, len(train_file_list), len(val_file_list)))
# Out:
# [fold 2] train: 17100, val: 4275

# %% [markdown]
# ## run training

# %%
set_seed(settings["globals"]["seed"])
device = torch.device(settings["globals"]["device"])
output_dir = Path(settings["globals"]["output_dir"])

# # # get loader
train_loader, val_loader = get_loaders_for_training(
    settings["dataset"]["params"], settings["loader"], train_file_list, val_file_list)

# # # get model
model = get_model()
model = model.to(device)
model
# # # get optimizer
optimizer = getattr(
    torch.optim, settings["optimizer"]["name"]
)(model.parameters(), **settings["optimizer"]["params"])

# # # get scheduler
scheduler = getattr(
    torch.optim.lr_scheduler, settings["scheduler"]["name"]
)(optimizer, **settings["scheduler"]["params"])

# # # get loss
loss_func = getattr(nn, settings["loss"]["name"])(**settings["loss"]["params"])

# # # create training manager
trigger = None

manager = ppe.training.ExtensionsManager(
    model, optimizer, settings["globals"]["num_epochs"],
    iters_per_epoch=len(train_loader),
    stop_trigger=trigger,
    out_dir=output_dir
)

# # # set manager extensions
manager = set_extensions(
    manager, settings, model, device,
    val_loader, optimizer, loss_func,
)
# Out:
# Downloading: "https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-weights/regnety_032_ra-7f2439f9.pth" to /root/.cache/torch/checkpoints/regnety_032_ra-7f2439f9.pth

# %%
# # runtraining
train_loop(
    manager, settings, model, device,
    train_loader, optimizer, scheduler, loss_func)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:5: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   """
# HBox(children=(FloatProgress(value=0.0, max=342.0), HTML(value='')))
# epoch       iteration   lr          train/loss  val/loss    elapsed_time
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [#.................................................]  2.33%
#          1 iterations
#     2.1172 iters/sec. Estimated time to finish: 0:00:19.837724.
# validation [##................................................]  4.65%
#          2 iterations
#    0.30316 iters/sec. Estimated time to finish: 0:02:15.240311.
# validation [###...............................................]  6.98%
#          3 iterations
#    0.42446 iters/sec. Estimated time to finish: 0:01:34.237340.
# validation [####..............................................]  9.30%
#          4 iterations
#    0.29867 iters/sec. Estimated time to finish: 0:02:10.580615.
# validation [#####.............................................] 11.63%
#          5 iterations
#    0.36065 iters/sec. Estimated time to finish: 0:01:45.364523.
# validation [######............................................] 13.95%
#          6 iterations
#    0.28736 iters/sec. Estimated time to finish: 0:02:08.756440.
# validation [########..........................................] 16.28%
#          7 iterations
#    0.32783 iters/sec. Estimated time to finish: 0:01:49.814095.
# validation [#########.........................................] 18.60%
#          8 iterations
#    0.28359 iters/sec. Estimated time to finish: 0:02:03.416432.
# validation [##########........................................] 20.93%
#          9 iterations
#    0.31383 iters/sec. Estimated time to finish: 0:01:48.337603.
# validation [###########.......................................] 23.26%
#         10 iterations
#    0.29025 iters/sec. Estimated time to finish: 0:01:53.695257.
# validation [############......................................] 25.58%
#         11 iterations
#    0.31497 iters/sec. Estimated time to finish: 0:01:41.595570.
# validation [#############.....................................] 27.91%
#         12 iterations
#    0.29024 iters/sec. Estimated time to finish: 0:01:46.806334.
# validation [###############...................................] 30.23%
#         13 iterations
#    0.31071 iters/sec. Estimated time to finish: 0:01:36.551791.
# validation [################..................................] 32.56%
#         14 iterations
#    0.29319 iters/sec. Estimated time to finish: 0:01:38.913003.
# validation [#################.................................] 34.88%
#         15 iterations
#    0.31107 iters/sec. Estimated time to finish: 0:01:30.012620.
# validation [##################................................] 37.21%
#         16 iterations
#    0.29268 iters/sec. Estimated time to finish: 0:01:32.250419.
# validation [###################...............................] 39.53%
#         17 iterations
#    0.30833 iters/sec. Estimated time to finish: 0:01:24.326201.
# validation [####################..............................] 41.86%
#         18 iterations
#    0.29102 iters/sec. Estimated time to finish: 0:01:25.903301.
# validation [######################............................] 44.19%
#         19 iterations
#    0.30487 iters/sec. Estimated time to finish: 0:01:18.721005.
# validation [#######################...........................] 46.51%
#         20 iterations
#    0.29218 iters/sec. Estimated time to finish: 0:01:18.717654.
# validation [########################..........................] 48.84%
#         21 iterations
#    0.30467 iters/sec. Estimated time to finish: 0:01:12.209025.
# validation [#########################.........................] 51.16%
#         22 iterations
#     0.2927 iters/sec. Estimated time to finish: 0:01:11.745316.
# validation [##########################........................] 53.49%
#         23 iterations
#    0.30409 iters/sec. Estimated time to finish: 0:01:05.770510.
# validation [###########################.......................] 55.81%
#         24 iterations
#    0.29273 iters/sec. Estimated time to finish: 0:01:04.905721.
# validation [#############################.....................] 58.14%
#         25 iterations
#     0.3032 iters/sec. Estimated time to finish: 0:00:59.367426.
# validation [##############################....................] 60.47%
#         26 iterations
#    0.28887 iters/sec. Estimated time to finish: 0:00:58.850650.
# validation [###############################...................] 62.79%
#         27 iterations
#    0.29842 iters/sec. Estimated time to finish: 0:00:53.616527.
# validation [################################..................] 65.12%
#         28 iterations
#    0.28957 iters/sec. Estimated time to finish: 0:00:51.800269.
# validation [#################################.................] 67.44%
#         29 iterations
#    0.29846 iters/sec. Estimated time to finish: 0:00:46.907401.
# validation [##################################................] 69.77%
#         30 iterations
#    0.28632 iters/sec. Estimated time to finish: 0:00:45.403175.
# validation [####################################..............] 72.09%
#         31 iterations
#    0.29454 iters/sec. Estimated time to finish: 0:00:40.741148.
# validation [#####################################.............] 74.42%
#         32 iterations
#    0.28593 iters/sec. Estimated time to finish: 0:00:38.471495.
# validation [######################################............] 76.74%
#         33 iterations
#    0.29359 iters/sec. Estimated time to finish: 0:00:34.060535.
# validation [#######################################...........] 79.07%
#         34 iterations
#    0.28206 iters/sec. Estimated time to finish: 0:00:31.907778.
# validation [########################################..........] 81.40%
#         35 iterations
#    0.28923 iters/sec. Estimated time to finish: 0:00:27.659444.
# validation [#########################################.........] 83.72%
#         36 iterations
#    0.28463 iters/sec. Estimated time to finish: 0:00:24.593424.
# validation [###########################################.......] 86.05%
#         37 iterations
#    0.29145 iters/sec. Estimated time to finish: 0:00:20.586669.
# validation [############################################......] 88.37%
#         38 iterations
#    0.28363 iters/sec. Estimated time to finish: 0:00:17.628388.
# validation [#############################################.....] 90.70%
#         39 iterations
#    0.29008 iters/sec. Estimated time to finish: 0:00:13.789236.
# validation [##############################################....] 93.02%
#         40 iterations
#    0.28636 iters/sec. Estimated time to finish: 0:00:10.476341.
# validation [###############################################...] 95.35%
#         41 iterations
#    0.29253 iters/sec. Estimated time to finish: 0:00:06.836875.
# validation [################################################..] 97.67%
#         42 iterations
#    0.29379 iters/sec. Estimated time to finish: 0:00:03.403769.
# 1           342         0.000904508  0.0320773   0.0251469   812.3
#
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [#.................................................]  2.33%
#          1 iterations
#     2.0627 iters/sec. Estimated time to finish: 0:00:20.361284.
# validation [##................................................]  4.65%
#          2 iterations
#    0.35024 iters/sec. Estimated time to finish: 0:01:57.063046.
# validation [###...............................................]  6.98%
#          3 iterations
#    0.48533 iters/sec. Estimated time to finish: 0:01:22.418302.
# validation [####..............................................]  9.30%
#          4 iterations
#     0.3296 iters/sec. Estimated time to finish: 0:01:58.323554.
# validation [#####.............................................] 11.63%
#          5 iterations
#    0.39652 iters/sec. Estimated time to finish: 0:01:35.834727.
# validation [######............................................] 13.95%
#          6 iterations
#    0.33495 iters/sec. Estimated time to finish: 0:01:50.464674.
# validation [########..........................................] 16.28%
#          7 iterations
#    0.38078 iters/sec. Estimated time to finish: 0:01:34.541583.
# validation [#########.........................................] 18.60%
#          8 iterations
#    0.32861 iters/sec. Estimated time to finish: 0:01:46.508869.
# validation [##########........................................] 20.93%
#          9 iterations
#    0.36241 iters/sec. Estimated time to finish: 0:01:33.815113.
# validation [###########.......................................] 23.26%
#         10 iterations
#    0.31788 iters/sec. Estimated time to finish: 0:01:43.814391.
# validation [############......................................] 25.58%
#         11 iterations
#    0.34452 iters/sec. Estimated time to finish: 0:01:32.882490.
# validation [#############.....................................] 27.91%
#         12 iterations
#    0.31984 iters/sec. Estimated time to finish: 0:01:36.924148.
# validation [###############...................................] 30.23%
#         13 iterations
#    0.34222 iters/sec. Estimated time to finish: 0:01:27.664145.
# validation [################..................................] 32.56%
#         14 iterations
#    0.32248 iters/sec. Estimated time to finish: 0:01:29.928953.
# validation [#################.................................] 34.88%
#         15 iterations
#    0.34171 iters/sec. Estimated time to finish: 0:01:21.941141.
# validation [##################................................] 37.21%
#         16 iterations
#    0.32271 iters/sec. Estimated time to finish: 0:01:23.665186.
# validation [###################...............................] 39.53%
#         17 iterations
#    0.33964 iters/sec. Estimated time to finish: 0:01:16.550561.
# validation [####################..............................] 41.86%
#         18 iterations
#    0.32648 iters/sec. Estimated time to finish: 0:01:16.574266.
# validation [######################............................] 44.19%
#         19 iterations
#    0.34116 iters/sec. Estimated time to finish: 0:01:10.347863.
# validation [#######################...........................] 46.51%
#         20 iterations
#    0.32712 iters/sec. Estimated time to finish: 0:01:10.311120.
# validation [########################..........................] 48.84%
#         21 iterations
#    0.34029 iters/sec. Estimated time to finish: 0:01:04.650203.
# validation [#########################.........................] 51.16%
#         22 iterations
#    0.32759 iters/sec. Estimated time to finish: 0:01:04.104555.
# validation [##########################........................] 53.49%
#         23 iterations
#    0.33987 iters/sec. Estimated time to finish: 0:00:58.846872.
# validation [###########################.......................] 55.81%
#         24 iterations
#    0.32622 iters/sec. Estimated time to finish: 0:00:58.242385.
# validation [#############################.....................] 58.14%
#         25 iterations
#    0.33694 iters/sec. Estimated time to finish: 0:00:53.422604.
# validation [##############################....................] 60.47%
#         26 iterations
#    0.32599 iters/sec. Estimated time to finish: 0:00:52.149074.
# validation [###############################...................] 62.79%
#         27 iterations
#    0.33653 iters/sec. Estimated time to finish: 0:00:47.543795.
# validation [################################..................] 65.12%
#         28 iterations
#     0.3277 iters/sec. Estimated time to finish: 0:00:45.773842.
# validation [#################################.................] 67.44%
#         29 iterations
#    0.33728 iters/sec. Estimated time to finish: 0:00:41.509051.
# validation [##################################................] 69.77%
#         30 iterations
#    0.32184 iters/sec. Estimated time to finish: 0:00:40.392570.
# validation [####################################..............] 72.09%
#         31 iterations
#     0.3309 iters/sec. Estimated time to finish: 0:00:36.265085.
# validation [#####################################.............] 74.42%
#         32 iterations
#    0.32109 iters/sec. Estimated time to finish: 0:00:34.258593.
# validation [######################################............] 76.74%
#         33 iterations
#    0.32955 iters/sec. Estimated time to finish: 0:00:30.344830.
# validation [#######################################...........] 79.07%
#         34 iterations
#    0.32004 iters/sec. Estimated time to finish: 0:00:28.121306.
# validation [########################################..........] 81.40%
#         35 iterations
#    0.32796 iters/sec. Estimated time to finish: 0:00:24.393242.
# validation [#########################################.........] 83.72%
#         36 iterations
#    0.32415 iters/sec. Estimated time to finish: 0:00:21.595212.
# validation [###########################################.......] 86.05%
#         37 iterations
#    0.33168 iters/sec. Estimated time to finish: 0:00:18.089856.
# validation [############################################......] 88.37%
#         38 iterations
#    0.32306 iters/sec. Estimated time to finish: 0:00:15.476819.
# validation [#############################################.....] 90.70%
#         39 iterations
#    0.33023 iters/sec. Estimated time to finish: 0:00:12.112777.
# validation [##############################################....] 93.02%
#         40 iterations
#    0.32413 iters/sec. Estimated time to finish: 0:00:09.255472.
# validation [###############################################...] 95.35%
#         41 iterations
#    0.33098 iters/sec. Estimated time to finish: 0:00:06.042700.
# validation [################################################..] 97.67%
#         42 iterations
#    0.33308 iters/sec. Estimated time to finish: 0:00:03.002281.
# 2           684         0.000654508  0.0246815   0.0230148   1548.38
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [#.................................................]  2.33%
#          1 iterations
#     2.1257 iters/sec. Estimated time to finish: 0:00:19.757805.
# validation [##................................................]  4.65%
#          2 iterations
#    0.30727 iters/sec. Estimated time to finish: 0:02:13.431398.
# validation [###...............................................]  6.98%
#          3 iterations
#    0.42932 iters/sec. Estimated time to finish: 0:01:33.171326.
# validation [####..............................................]  9.30%
#          4 iterations
#    0.29895 iters/sec. Estimated time to finish: 0:02:10.457091.
# validation [#####.............................................] 11.63%
#          5 iterations
#    0.36107 iters/sec. Estimated time to finish: 0:01:45.242461.
# validation [######............................................] 13.95%
#          6 iterations
#    0.30278 iters/sec. Estimated time to finish: 0:02:02.202473.
# validation [########..........................................] 16.28%
#          7 iterations
#    0.34499 iters/sec. Estimated time to finish: 0:01:44.350691.
# validation [#########.........................................] 18.60%
#          8 iterations
#    0.30299 iters/sec. Estimated time to finish: 0:01:55.514774.
# validation [##########........................................] 20.93%
#          9 iterations
#    0.33492 iters/sec. Estimated time to finish: 0:01:41.517244.
# validation [###########.......................................] 23.26%
#         10 iterations
#    0.30934 iters/sec. Estimated time to finish: 0:01:46.677621.
# validation [############......................................] 25.58%
#         11 iterations
#    0.33522 iters/sec. Estimated time to finish: 0:01:35.459333.
# validation [#############.....................................] 27.91%
#         12 iterations
#    0.30877 iters/sec. Estimated time to finish: 0:01:40.399126.
# validation [###############...................................] 30.23%
#         13 iterations
#    0.33042 iters/sec. Estimated time to finish: 0:01:30.793488.
# validation [################..................................] 32.56%
#         14 iterations
#    0.31162 iters/sec. Estimated time to finish: 0:01:33.062011.
# validation [#################.................................] 34.88%
#         15 iterations
#     0.3304 iters/sec. Estimated time to finish: 0:01:24.746719.
# validation [##################................................] 37.21%
#         16 iterations
#    0.31411 iters/sec. Estimated time to finish: 0:01:25.958505.
# validation [###################...............................] 39.53%
#         17 iterations
#    0.33066 iters/sec. Estimated time to finish: 0:01:18.630423.
# validation [####################..............................] 41.86%
#         18 iterations
#    0.31655 iters/sec. Estimated time to finish: 0:01:18.976682.
# validation [######################............................] 44.19%
#         19 iterations
#    0.33137 iters/sec. Estimated time to finish: 0:01:12.426542.
# validation [#######################...........................] 46.51%
#         20 iterations
#    0.31892 iters/sec. Estimated time to finish: 0:01:12.118284.
# validation [########################..........................] 48.84%
#         21 iterations
#    0.33223 iters/sec. Estimated time to finish: 0:01:06.218793.
# validation [#########################.........................] 51.16%
#         22 iterations
#    0.32175 iters/sec. Estimated time to finish: 0:01:05.268720.
# validation [##########################........................] 53.49%
#         23 iterations
#    0.33408 iters/sec. Estimated time to finish: 0:00:59.866672.
# validation [###########################.......................] 55.81%
#         24 iterations
#    0.32347 iters/sec. Estimated time to finish: 0:00:58.737294.
# validation [#############################.....................] 58.14%
#         25 iterations
#    0.33483 iters/sec. Estimated time to finish: 0:00:53.758602.
# validation [##############################....................] 60.47%
#         26 iterations
#    0.32579 iters/sec. Estimated time to finish: 0:00:52.180792.
# validation [###############################...................] 62.79%
#         27 iterations
#    0.33634 iters/sec. Estimated time to finish: 0:00:47.570548.
# validation [################################..................] 65.12%
#         28 iterations
#     0.3281 iters/sec. Estimated time to finish: 0:00:45.717581.
# validation [#################################.................] 67.44%
#         29 iterations
#    0.33791 iters/sec. Estimated time to finish: 0:00:41.430671.
# validation [##################################................] 69.77%
#         30 iterations
#    0.32673 iters/sec. Estimated time to finish: 0:00:39.787650.
# validation [####################################..............] 72.09%
#         31 iterations
#     0.3359 iters/sec. Estimated time to finish: 0:00:35.724873.
# validation [#####################################.............] 74.42%
#         32 iterations
#    0.32437 iters/sec. Estimated time to finish: 0:00:33.912321.
# validation [######################################............] 76.74%
#         33 iterations
#    0.33289 iters/sec. Estimated time to finish: 0:00:30.039692.
# validation [#######################################...........] 79.07%
#         34 iterations
#    0.32201 iters/sec. Estimated time to finish: 0:00:27.949713.
# validation [########################################..........] 81.40%
#         35 iterations
#       0.33 iters/sec. Estimated time to finish: 0:00:24.242383.
# validation [#########################################.........] 83.72%
#         36 iterations
#    0.32541 iters/sec. Estimated time to finish: 0:00:21.511276.
# validation [###########################################.......] 86.05%
#         37 iterations
#    0.33304 iters/sec. Estimated time to finish: 0:00:18.015797.
# validation [############################################......] 88.37%
#         38 iterations
#    0.32421 iters/sec. Estimated time to finish: 0:00:15.421929.
# validation [#############################################.....] 90.70%
#         39 iterations
#    0.33141 iters/sec. Estimated time to finish: 0:00:12.069657.
# validation [##############################################....] 93.02%
#         40 iterations
#    0.32566 iters/sec. Estimated time to finish: 0:00:09.212110.
# validation [###############################################...] 95.35%
#         41 iterations
#    0.33253 iters/sec. Estimated time to finish: 0:00:06.014533.
# validation [################################################..] 97.67%
#         42 iterations
#    0.33419 iters/sec. Estimated time to finish: 0:00:02.992293.
# 3           1026        0.000345492  0.0218432   0.0218434   2258.83
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [#.................................................]  2.33%
#          1 iterations
#     2.0624 iters/sec. Estimated time to finish: 0:00:20.364548.
# validation [##................................................]  4.65%
#          2 iterations
#    0.38355 iters/sec. Estimated time to finish: 0:01:46.896193.
# validation [###...............................................]  6.98%
#          3 iterations
#    0.52781 iters/sec. Estimated time to finish: 0:01:15.784960.
# validation [####..............................................]  9.30%
#          4 iterations
#    0.36341 iters/sec. Estimated time to finish: 0:01:47.317606.
# validation [#####.............................................] 11.63%
#          5 iterations
#    0.43536 iters/sec. Estimated time to finish: 0:01:27.283346.
# validation [######............................................] 13.95%
#          6 iterations
#    0.35825 iters/sec. Estimated time to finish: 0:01:43.278477.
# validation [########..........................................] 16.28%
#          7 iterations
#    0.40657 iters/sec. Estimated time to finish: 0:01:28.545931.
# validation [#########.........................................] 18.60%
#          8 iterations
#    0.34866 iters/sec. Estimated time to finish: 0:01:40.384815.
# validation [##########........................................] 20.93%
#          9 iterations
#     0.3842 iters/sec. Estimated time to finish: 0:01:28.495466.
# validation [###########.......................................] 23.26%
#         10 iterations
#    0.35142 iters/sec. Estimated time to finish: 0:01:33.905500.
# validation [############......................................] 25.58%
#         11 iterations
#    0.38025 iters/sec. Estimated time to finish: 0:01:24.156214.
# validation [#############.....................................] 27.91%
#         12 iterations
#    0.35731 iters/sec. Estimated time to finish: 0:01:26.760099.
# validation [###############...................................] 30.23%
#         13 iterations
#    0.38174 iters/sec. Estimated time to finish: 0:01:18.586581.
# validation [################..................................] 32.56%
#         14 iterations
#    0.36378 iters/sec. Estimated time to finish: 0:01:19.718997.
# validation [#################.................................] 34.88%
#         15 iterations
#    0.38498 iters/sec. Estimated time to finish: 0:01:12.730765.
# validation [##################................................] 37.21%
#         16 iterations
#     0.3562 iters/sec. Estimated time to finish: 0:01:15.801115.
# validation [###################...............................] 39.53%
#         17 iterations
#    0.37449 iters/sec. Estimated time to finish: 0:01:09.427140.
# validation [####################..............................] 41.86%
#         18 iterations
#    0.35819 iters/sec. Estimated time to finish: 0:01:09.796130.
# validation [######################............................] 44.19%
#         19 iterations
#    0.37452 iters/sec. Estimated time to finish: 0:01:04.082164.
# validation [#######################...........................] 46.51%
#         20 iterations
#      0.358 iters/sec. Estimated time to finish: 0:01:04.246069.
# validation [########################..........................] 48.84%
#         21 iterations
#    0.37271 iters/sec. Estimated time to finish: 0:00:59.026826.
# validation [#########################.........................] 51.16%
#         22 iterations
#    0.35957 iters/sec. Estimated time to finish: 0:00:58.403799.
# validation [##########################........................] 53.49%
#         23 iterations
#    0.37296 iters/sec. Estimated time to finish: 0:00:53.624488.
# validation [###########################.......................] 55.81%
#         24 iterations
#    0.35979 iters/sec. Estimated time to finish: 0:00:52.808047.
# validation [#############################.....................] 58.14%
#         25 iterations
#    0.37206 iters/sec. Estimated time to finish: 0:00:48.378724.
# validation [##############################....................] 60.47%
#         26 iterations
#    0.36004 iters/sec. Estimated time to finish: 0:00:47.217422.
# validation [###############################...................] 62.79%
#         27 iterations
#    0.37142 iters/sec. Estimated time to finish: 0:00:43.077399.
# validation [################################..................] 65.12%
#         28 iterations
#    0.36213 iters/sec. Estimated time to finish: 0:00:41.421981.
# validation [#################################.................] 67.44%
#         29 iterations
#    0.37277 iters/sec. Estimated time to finish: 0:00:37.556279.
# validation [##################################................] 69.77%
#         30 iterations
#    0.35743 iters/sec. Estimated time to finish: 0:00:36.370813.
# validation [####################################..............] 72.09%
#         31 iterations
#     0.3672 iters/sec. Estimated time to finish: 0:00:32.679534.
# validation [#####################################.............] 74.42%
#         32 iterations
#    0.35893 iters/sec. Estimated time to finish: 0:00:30.646558.
# validation [######################################............] 76.74%
#         33 iterations
#     0.3682 iters/sec. Estimated time to finish: 0:00:27.159203.
# validation [#######################################...........] 79.07%
#         34 iterations
#    0.35794 iters/sec. Estimated time to finish: 0:00:25.143956.
# validation [########################################..........] 81.40%
#         35 iterations
#    0.36664 iters/sec. Estimated time to finish: 0:00:21.819634.
# validation [#########################################.........] 83.72%
#         36 iterations
#    0.36059 iters/sec. Estimated time to finish: 0:00:19.412632.
# validation [###########################################.......] 86.05%
#         37 iterations
#    0.36884 iters/sec. Estimated time to finish: 0:00:16.267077.
# validation [############################################......] 88.37%
#         38 iterations
#    0.35823 iters/sec. Estimated time to finish: 0:00:13.957358.
# validation [#############################################.....] 90.70%
#         39 iterations
#    0.36603 iters/sec. Estimated time to finish: 0:00:10.928027.
# validation [##############################################....] 93.02%
#         40 iterations
#    0.35861 iters/sec. Estimated time to finish: 0:00:08.365531.
# validation [###############################################...] 95.35%
#         41 iterations
#    0.36603 iters/sec. Estimated time to finish: 0:00:05.463994.
# validation [################################################..] 97.67%
#         42 iterations
#    0.36806 iters/sec. Estimated time to finish: 0:00:02.716964.
# 4           1368        9.54915e-05  0.0193965   0.0188042   2959.47
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [#.................................................]  2.33%
#          1 iterations
#     2.0931 iters/sec. Estimated time to finish: 0:00:20.065663.
# validation [##................................................]  4.65%
#          2 iterations
#      0.316 iters/sec. Estimated time to finish: 0:02:09.748796.
# validation [###...............................................]  6.98%
#          3 iterations
#    0.44037 iters/sec. Estimated time to finish: 0:01:30.832303.
# validation [####..............................................]  9.30%
#          4 iterations
#    0.31014 iters/sec. Estimated time to finish: 0:02:05.749489.
# validation [#####.............................................] 11.63%
#          5 iterations
#    0.37398 iters/sec. Estimated time to finish: 0:01:41.609698.
# validation [######............................................] 13.95%
#          6 iterations
#    0.31167 iters/sec. Estimated time to finish: 0:01:58.714519.
# validation [########..........................................] 16.28%
#          7 iterations
#    0.35496 iters/sec. Estimated time to finish: 0:01:41.420922.
# validation [#########.........................................] 18.60%
#          8 iterations
#    0.30005 iters/sec. Estimated time to finish: 0:01:56.648914.
# validation [##########........................................] 20.93%
#          9 iterations
#    0.33166 iters/sec. Estimated time to finish: 0:01:42.514142.
# validation [###########.......................................] 23.26%
#         10 iterations
#    0.30423 iters/sec. Estimated time to finish: 0:01:48.471274.
# validation [############......................................] 25.58%
#         11 iterations
#    0.32994 iters/sec. Estimated time to finish: 0:01:36.987291.
# validation [#############.....................................] 27.91%
#         12 iterations
#    0.31031 iters/sec. Estimated time to finish: 0:01:39.899610.
# validation [###############...................................] 30.23%
#         13 iterations
#    0.33209 iters/sec. Estimated time to finish: 0:01:30.338013.
# validation [################..................................] 32.56%
#         14 iterations
#    0.31343 iters/sec. Estimated time to finish: 0:01:32.525703.
# validation [#################.................................] 34.88%
#         15 iterations
#    0.33231 iters/sec. Estimated time to finish: 0:01:24.258330.
# validation [##################................................] 37.21%
#         16 iterations
#    0.31387 iters/sec. Estimated time to finish: 0:01:26.023480.
# validation [###################...............................] 39.53%
#         17 iterations
#    0.33044 iters/sec. Estimated time to finish: 0:01:18.683698.
# validation [####################..............................] 41.86%
#         18 iterations
#    0.31615 iters/sec. Estimated time to finish: 0:01:19.077473.
# validation [######################............................] 44.19%
#         19 iterations
#    0.33097 iters/sec. Estimated time to finish: 0:01:12.513549.
# validation [#######################...........................] 46.51%
#         20 iterations
#    0.31642 iters/sec. Estimated time to finish: 0:01:12.688124.
# validation [########################..........................] 48.84%
#         21 iterations
#    0.32976 iters/sec. Estimated time to finish: 0:01:06.715386.
# validation [#########################.........................] 51.16%
#         22 iterations
#    0.31373 iters/sec. Estimated time to finish: 0:01:06.936459.
# validation [##########################........................] 53.49%
#         23 iterations
#    0.32579 iters/sec. Estimated time to finish: 0:01:01.389346.
# validation [###########################.......................] 55.81%
#         24 iterations
#    0.31309 iters/sec. Estimated time to finish: 0:01:00.684488.
# validation [#############################.....................] 58.14%
#         25 iterations
#    0.32414 iters/sec. Estimated time to finish: 0:00:55.531632.
# validation [##############################....................] 60.47%
#         26 iterations
#    0.31378 iters/sec. Estimated time to finish: 0:00:54.177993.
# validation [###############################...................] 62.79%
#         27 iterations
#    0.32401 iters/sec. Estimated time to finish: 0:00:49.381081.
# validation [################################..................] 65.12%
#         28 iterations
#    0.31559 iters/sec. Estimated time to finish: 0:00:47.530691.
# validation [#################################.................] 67.44%
#         29 iterations
#    0.32513 iters/sec. Estimated time to finish: 0:00:43.060291.
# validation [##################################................] 69.77%
#         30 iterations
#    0.31497 iters/sec. Estimated time to finish: 0:00:41.274113.
# validation [####################################..............] 72.09%
#         31 iterations
#    0.32387 iters/sec. Estimated time to finish: 0:00:37.052044.
# validation [#####################################.............] 74.42%
#         32 iterations
#    0.31469 iters/sec. Estimated time to finish: 0:00:34.954901.
# validation [######################################............] 76.74%
#         33 iterations
#    0.32303 iters/sec. Estimated time to finish: 0:00:30.956974.
# validation [#######################################...........] 79.07%
#         34 iterations
#     0.3129 iters/sec. Estimated time to finish: 0:00:28.763317.
# validation [########################################..........] 81.40%
#         35 iterations
#    0.32058 iters/sec. Estimated time to finish: 0:00:24.954524.
# validation [#########################################.........] 83.72%
#         36 iterations
#    0.31524 iters/sec. Estimated time to finish: 0:00:22.205428.
# validation [###########################################.......] 86.05%
#         37 iterations
#    0.32158 iters/sec. Estimated time to finish: 0:00:18.657735.
# validation [############################################......] 88.37%
#         38 iterations
#    0.31319 iters/sec. Estimated time to finish: 0:00:15.964980.
# validation [#############################################.....] 90.70%
#         39 iterations
#    0.32019 iters/sec. Estimated time to finish: 0:00:12.492618.
# validation [##############################################....] 93.02%
#         40 iterations
#    0.31372 iters/sec. Estimated time to finish: 0:00:09.562653.
# validation [###############################################...] 95.35%
#         41 iterations
#    0.32037 iters/sec. Estimated time to finish: 0:00:06.242862.
# validation [################################################..] 97.67%
#         42 iterations
#    0.32156 iters/sec. Estimated time to finish: 0:00:03.109808.
# 5           1710        0           0.0174104   0.0169198   3679.78
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [#.................................................]  2.33%
#          1 iterations
#     2.0821 iters/sec. Estimated time to finish: 0:00:20.171536.
# validation [##................................................]  4.65%
#          2 iterations
#    0.34607 iters/sec. Estimated time to finish: 0:01:58.472135.
# validation [###...............................................]  6.98%
#          3 iterations
#    0.47982 iters/sec. Estimated time to finish: 0:01:23.365107.
# validation [####..............................................]  9.30%
#          4 iterations
#    0.34768 iters/sec. Estimated time to finish: 0:01:52.173635.
# validation [#####.............................................] 11.63%
#          5 iterations
#    0.41746 iters/sec. Estimated time to finish: 0:01:31.026637.
# validation [######............................................] 13.95%
#          6 iterations
#    0.33934 iters/sec. Estimated time to finish: 0:01:49.036328.
# validation [########..........................................] 16.28%
#          7 iterations
#    0.38539 iters/sec. Estimated time to finish: 0:01:33.410842.
# validation [#########.........................................] 18.60%
#          8 iterations
#    0.33789 iters/sec. Estimated time to finish: 0:01:43.583114.
# validation [##########........................................] 20.93%
#          9 iterations
#    0.37271 iters/sec. Estimated time to finish: 0:01:31.224129.
# validation [###########.......................................] 23.26%
#         10 iterations
#    0.33596 iters/sec. Estimated time to finish: 0:01:38.226703.
# validation [############......................................] 25.58%
#         11 iterations
#    0.36367 iters/sec. Estimated time to finish: 0:01:27.992204.
# validation [#############.....................................] 27.91%
#         12 iterations
#    0.33634 iters/sec. Estimated time to finish: 0:01:32.167278.
# validation [###############...................................] 30.23%
#         13 iterations
#     0.3596 iters/sec. Estimated time to finish: 0:01:23.425601.
# validation [################..................................] 32.56%
#         14 iterations
#     0.3408 iters/sec. Estimated time to finish: 0:01:25.092679.
# validation [#################.................................] 34.88%
#         15 iterations
#    0.36102 iters/sec. Estimated time to finish: 0:01:17.557802.
# validation [##################................................] 37.21%
#         16 iterations
#    0.33674 iters/sec. Estimated time to finish: 0:01:20.180191.
# validation [###################...............................] 39.53%
#         17 iterations
#    0.35428 iters/sec. Estimated time to finish: 0:01:13.388335.
# validation [####################..............................] 41.86%
#         18 iterations
#    0.33854 iters/sec. Estimated time to finish: 0:01:13.846975.
# validation [######################............................] 44.19%
#         19 iterations
#    0.35419 iters/sec. Estimated time to finish: 0:01:07.759787.
# validation [#######################...........................] 46.51%
#         20 iterations
#    0.33939 iters/sec. Estimated time to finish: 0:01:07.768979.
# validation [########################..........................] 48.84%
#         21 iterations
#    0.35351 iters/sec. Estimated time to finish: 0:01:02.233853.
# validation [#########################.........................] 51.16%
#         22 iterations
#    0.33934 iters/sec. Estimated time to finish: 0:01:01.885564.
# validation [##########################........................] 53.49%
#         23 iterations
#    0.35216 iters/sec. Estimated time to finish: 0:00:56.792179.
# validation [###########################.......................] 55.81%
#         24 iterations
#    0.34073 iters/sec. Estimated time to finish: 0:00:55.763083.
# validation [#############################.....................] 58.14%
#         25 iterations
#    0.35256 iters/sec. Estimated time to finish: 0:00:51.055456.
# validation [##############################....................] 60.47%
#         26 iterations
#    0.34193 iters/sec. Estimated time to finish: 0:00:49.717761.
# validation [###############################...................] 62.79%
#         27 iterations
#    0.35287 iters/sec. Estimated time to finish: 0:00:45.342780.
# validation [################################..................] 65.12%
#         28 iterations
#    0.34436 iters/sec. Estimated time to finish: 0:00:43.559271.
# validation [#################################.................] 67.44%
#         29 iterations
#    0.35457 iters/sec. Estimated time to finish: 0:00:39.484961.
# validation [##################################................] 69.77%
#         30 iterations
#    0.34245 iters/sec. Estimated time to finish: 0:00:37.961319.
# validation [####################################..............] 72.09%
#         31 iterations
#    0.35198 iters/sec. Estimated time to finish: 0:00:34.093243.
# validation [#####################################.............] 74.42%
#         32 iterations
#    0.33944 iters/sec. Estimated time to finish: 0:00:32.406338.
# validation [######################################............] 76.74%
#         33 iterations
#    0.34829 iters/sec. Estimated time to finish: 0:00:28.711824.
# validation [#######################################...........] 79.07%
#         34 iterations
#    0.33716 iters/sec. Estimated time to finish: 0:00:26.693656.
# validation [########################################..........] 81.40%
#         35 iterations
#    0.34544 iters/sec. Estimated time to finish: 0:00:23.159047.
# validation [#########################################.........] 83.72%
#         36 iterations
#    0.33894 iters/sec. Estimated time to finish: 0:00:20.652507.
# validation [###########################################.......] 86.05%
#         37 iterations
#    0.34681 iters/sec. Estimated time to finish: 0:00:17.300550.
# validation [############################################......] 88.37%
#         38 iterations
#    0.33647 iters/sec. Estimated time to finish: 0:00:14.860330.
# validation [#############################################.....] 90.70%
#         39 iterations
#    0.34386 iters/sec. Estimated time to finish: 0:00:11.632562.
# validation [##############################################....] 93.02%
#         40 iterations
#    0.33685 iters/sec. Estimated time to finish: 0:00:08.906056.
# validation [###############################################...] 95.35%
#         41 iterations
#    0.34391 iters/sec. Estimated time to finish: 0:00:05.815500.
# validation [################################################..] 97.67%
#         42 iterations
#    0.34548 iters/sec. Estimated time to finish: 0:00:02.894557.
# 6           2052        9.54915e-05  0.0156018   0.0154983   4404.86
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [#.................................................]  2.33%
#          1 iterations
#      2.122 iters/sec. Estimated time to finish: 0:00:19.792663.
# validation [##................................................]  4.65%
#          2 iterations
#    0.34896 iters/sec. Estimated time to finish: 0:01:57.490440.
# validation [###...............................................]  6.98%
#          3 iterations
#    0.48308 iters/sec. Estimated time to finish: 0:01:22.801514.
# validation [####..............................................]  9.30%
#          4 iterations
#    0.34307 iters/sec. Estimated time to finish: 0:01:53.678060.
# validation [#####.............................................] 11.63%
#          5 iterations
#    0.41204 iters/sec. Estimated time to finish: 0:01:32.225089.
# validation [######............................................] 13.95%
#          6 iterations
#    0.32724 iters/sec. Estimated time to finish: 0:01:53.066914.
# validation [########..........................................] 16.28%
#          7 iterations
#    0.37188 iters/sec. Estimated time to finish: 0:01:36.806423.
# validation [#########.........................................] 18.60%
#          8 iterations
#    0.32704 iters/sec. Estimated time to finish: 0:01:47.021639.
# validation [##########........................................] 20.93%
#          9 iterations
#    0.36087 iters/sec. Estimated time to finish: 0:01:34.216948.
# validation [###########.......................................] 23.26%
#         10 iterations
#    0.32936 iters/sec. Estimated time to finish: 0:01:40.194522.
# validation [############......................................] 25.58%
#         11 iterations
#    0.35657 iters/sec. Estimated time to finish: 0:01:29.743447.
# validation [#############.....................................] 27.91%
#         12 iterations
#    0.33748 iters/sec. Estimated time to finish: 0:01:31.855976.
# validation [###############...................................] 30.23%
#         13 iterations
#    0.36082 iters/sec. Estimated time to finish: 0:01:23.144215.
# validation [################..................................] 32.56%
#         14 iterations
#    0.33995 iters/sec. Estimated time to finish: 0:01:25.306323.
# validation [#################.................................] 34.88%
#         15 iterations
#    0.36008 iters/sec. Estimated time to finish: 0:01:17.760876.
# validation [##################................................] 37.21%
#         16 iterations
#    0.34222 iters/sec. Estimated time to finish: 0:01:18.896574.
# validation [###################...............................] 39.53%
#         17 iterations
#    0.35993 iters/sec. Estimated time to finish: 0:01:12.236196.
# validation [####################..............................] 41.86%
#         18 iterations
#    0.34542 iters/sec. Estimated time to finish: 0:01:12.374851.
# validation [######################............................] 44.19%
#         19 iterations
#    0.36136 iters/sec. Estimated time to finish: 0:01:06.415294.
# validation [#######################...........................] 46.51%
#         20 iterations
#    0.34613 iters/sec. Estimated time to finish: 0:01:06.448366.
# validation [########################..........................] 48.84%
#         21 iterations
#    0.36052 iters/sec. Estimated time to finish: 0:01:01.023561.
# validation [#########################.........................] 51.16%
#         22 iterations
#    0.34539 iters/sec. Estimated time to finish: 0:01:00.800881.
# validation [##########################........................] 53.49%
#         23 iterations
#     0.3584 iters/sec. Estimated time to finish: 0:00:55.803646.
# validation [###########################.......................] 55.81%
#         24 iterations
#    0.34611 iters/sec. Estimated time to finish: 0:00:54.896424.
# validation [#############################.....................] 58.14%
#         25 iterations
#    0.35808 iters/sec. Estimated time to finish: 0:00:50.267558.
# validation [##############################....................] 60.47%
#         26 iterations
#    0.34652 iters/sec. Estimated time to finish: 0:00:49.059315.
# validation [###############################...................] 62.79%
#         27 iterations
#    0.35756 iters/sec. Estimated time to finish: 0:00:44.747806.
# validation [################################..................] 65.12%
#         28 iterations
#    0.34707 iters/sec. Estimated time to finish: 0:00:43.219416.
# validation [#################################.................] 67.44%
#         29 iterations
#    0.35733 iters/sec. Estimated time to finish: 0:00:39.179677.
# validation [##################################................] 69.77%
#         30 iterations
#    0.34154 iters/sec. Estimated time to finish: 0:00:38.063094.
# validation [####################################..............] 72.09%
#         31 iterations
#    0.35102 iters/sec. Estimated time to finish: 0:00:34.185637.
# validation [#####################################.............] 74.42%
#         32 iterations
#    0.34191 iters/sec. Estimated time to finish: 0:00:32.171999.
# validation [######################################............] 76.74%
#         33 iterations
#    0.35081 iters/sec. Estimated time to finish: 0:00:28.505521.
# validation [#######################################...........] 79.07%
#         34 iterations
#    0.34107 iters/sec. Estimated time to finish: 0:00:26.387627.
# validation [########################################..........] 81.40%
#         35 iterations
#     0.3494 iters/sec. Estimated time to finish: 0:00:22.896609.
# validation [#########################################.........] 83.72%
#         36 iterations
#    0.34388 iters/sec. Estimated time to finish: 0:00:20.355659.
# validation [###########################################.......] 86.05%
#         37 iterations
#    0.35185 iters/sec. Estimated time to finish: 0:00:17.052933.
# validation [############################################......] 88.37%
#         38 iterations
#    0.34356 iters/sec. Estimated time to finish: 0:00:14.553564.
# validation [#############################################.....] 90.70%
#         39 iterations
#    0.35111 iters/sec. Estimated time to finish: 0:00:11.392482.
# validation [##############################################....] 93.02%
#         40 iterations
#    0.34732 iters/sec. Estimated time to finish: 0:00:08.637469.
# validation [###############################################...] 95.35%
#         41 iterations
#    0.35456 iters/sec. Estimated time to finish: 0:00:05.640763.
# validation [################################################..] 97.67%
#         42 iterations
# ...
#         28 iterations
#     0.2784 iters/sec. Estimated time to finish: 0:00:53.879330.
# validation [#################################.................] 67.44%
#         29 iterations
#      0.287 iters/sec. Estimated time to finish: 0:00:48.781333.
# validation [##################################................] 69.77%
#         30 iterations
#    0.27543 iters/sec. Estimated time to finish: 0:00:47.198247.
# validation [####################################..............] 72.09%
#         31 iterations
#    0.28339 iters/sec. Estimated time to finish: 0:00:42.344252.
# validation [#####################################.............] 74.42%
#         32 iterations
#     0.2762 iters/sec. Estimated time to finish: 0:00:39.826889.
# validation [######################################............] 76.74%
#         33 iterations
#    0.28368 iters/sec. Estimated time to finish: 0:00:35.251469.
# validation [#######################################...........] 79.07%
#         34 iterations
#     0.2753 iters/sec. Estimated time to finish: 0:00:32.691897.
# validation [########################################..........] 81.40%
#         35 iterations
#    0.28233 iters/sec. Estimated time to finish: 0:00:28.336094.
# validation [#########################################.........] 83.72%
#         36 iterations
#    0.27652 iters/sec. Estimated time to finish: 0:00:25.315034.
# validation [###########################################.......] 86.05%
#         37 iterations
#    0.28317 iters/sec. Estimated time to finish: 0:00:21.188871.
# validation [############################################......] 88.37%
#         38 iterations
#    0.27653 iters/sec. Estimated time to finish: 0:00:18.081350.
# validation [#############################################.....] 90.70%
#         39 iterations
#    0.28282 iters/sec. Estimated time to finish: 0:00:14.143049.
# validation [##############################################....] 93.02%
#         40 iterations
#    0.27833 iters/sec. Estimated time to finish: 0:00:10.778722.
# validation [###############################################...] 95.35%
#         41 iterations
#    0.28436 iters/sec. Estimated time to finish: 0:00:07.033357.
# validation [################################################..] 97.67%
#         42 iterations
#    0.28579 iters/sec. Estimated time to finish: 0:00:03.499077.
# 43          14706       0.000345492  0.00286178  0.0117531   30537.6
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [#.................................................]  2.33%
#          1 iterations
#     2.0701 iters/sec. Estimated time to finish: 0:00:20.288475.
# validation [##................................................]  4.65%
#          2 iterations
#    0.31996 iters/sec. Estimated time to finish: 0:02:08.142444.
# validation [###...............................................]  6.98%
#          3 iterations
#    0.44641 iters/sec. Estimated time to finish: 0:01:29.604635.
# validation [####..............................................]  9.30%
#          4 iterations
#    0.28864 iters/sec. Estimated time to finish: 0:02:15.114406.
# validation [#####.............................................] 11.63%
#          5 iterations
#    0.34891 iters/sec. Estimated time to finish: 0:01:48.910379.
# validation [######............................................] 13.95%
#          6 iterations
#    0.28019 iters/sec. Estimated time to finish: 0:02:12.054522.
# validation [########..........................................] 16.28%
#          7 iterations
#    0.31975 iters/sec. Estimated time to finish: 0:01:52.586748.
# validation [#########.........................................] 18.60%
#          8 iterations
#    0.27646 iters/sec. Estimated time to finish: 0:02:06.598338.
# validation [##########........................................] 20.93%
#          9 iterations
#    0.30598 iters/sec. Estimated time to finish: 0:01:51.119907.
# validation [###########.......................................] 23.26%
#         10 iterations
#    0.28355 iters/sec. Estimated time to finish: 0:01:56.382363.
# validation [############......................................] 25.58%
#         11 iterations
#    0.30771 iters/sec. Estimated time to finish: 0:01:43.994410.
# validation [#############.....................................] 27.91%
#         12 iterations
#    0.28539 iters/sec. Estimated time to finish: 0:01:48.623479.
# validation [###############...................................] 30.23%
#         13 iterations
#    0.30575 iters/sec. Estimated time to finish: 0:01:38.118715.
# validation [################..................................] 32.56%
#         14 iterations
#    0.28824 iters/sec. Estimated time to finish: 0:01:40.610901.
# validation [#################.................................] 34.88%
#         15 iterations
#    0.30588 iters/sec. Estimated time to finish: 0:01:31.539526.
# validation [##################................................] 37.21%
#         16 iterations
#    0.28616 iters/sec. Estimated time to finish: 0:01:34.354409.
# validation [###################...............................] 39.53%
#         17 iterations
#    0.30151 iters/sec. Estimated time to finish: 0:01:26.231790.
# validation [####################..............................] 41.86%
#         18 iterations
#    0.29016 iters/sec. Estimated time to finish: 0:01:26.159705.
# validation [######################............................] 44.19%
#         19 iterations
#    0.30398 iters/sec. Estimated time to finish: 0:01:18.952789.
# validation [#######################...........................] 46.51%
#         20 iterations
#    0.29278 iters/sec. Estimated time to finish: 0:01:18.556952.
# validation [########################..........................] 48.84%
#         21 iterations
#    0.30528 iters/sec. Estimated time to finish: 0:01:12.065122.
# validation [#########################.........................] 51.16%
#         22 iterations
#    0.29212 iters/sec. Estimated time to finish: 0:01:11.888194.
# validation [##########################........................] 53.49%
#         23 iterations
#    0.30349 iters/sec. Estimated time to finish: 0:01:05.899661.
# validation [###########################.......................] 55.81%
#         24 iterations
#     0.2912 iters/sec. Estimated time to finish: 0:01:05.246987.
# validation [#############################.....................] 58.14%
#         25 iterations
#     0.3016 iters/sec. Estimated time to finish: 0:00:59.681454.
# validation [##############################....................] 60.47%
#         26 iterations
#    0.29161 iters/sec. Estimated time to finish: 0:00:58.296518.
# validation [###############################...................] 62.79%
#         27 iterations
#    0.30124 iters/sec. Estimated time to finish: 0:00:53.113414.
# validation [################################..................] 65.12%
#         28 iterations
#    0.29358 iters/sec. Estimated time to finish: 0:00:51.093626.
# validation [#################################.................] 67.44%
#         29 iterations
#    0.30257 iters/sec. Estimated time to finish: 0:00:46.270756.
# validation [##################################................] 69.77%
#         30 iterations
#    0.29049 iters/sec. Estimated time to finish: 0:00:44.751271.
# validation [####################################..............] 72.09%
#         31 iterations
#    0.29875 iters/sec. Estimated time to finish: 0:00:40.167552.
# validation [#####################################.............] 74.42%
#         32 iterations
#    0.29072 iters/sec. Estimated time to finish: 0:00:37.837181.
# validation [######################################............] 76.74%
#         33 iterations
#     0.2985 iters/sec. Estimated time to finish: 0:00:33.501230.
# validation [#######################################...........] 79.07%
#         34 iterations
#    0.28895 iters/sec. Estimated time to finish: 0:00:31.147330.
# validation [########################################..........] 81.40%
#         35 iterations
#    0.29627 iters/sec. Estimated time to finish: 0:00:27.002786.
# validation [#########################################.........] 83.72%
#         36 iterations
#     0.2918 iters/sec. Estimated time to finish: 0:00:23.989256.
# validation [###########################################.......] 86.05%
#         37 iterations
#    0.29877 iters/sec. Estimated time to finish: 0:00:20.082456.
# validation [############################################......] 88.37%
#         38 iterations
#    0.28953 iters/sec. Estimated time to finish: 0:00:17.269402.
# validation [#############################################.....] 90.70%
#         39 iterations
#    0.29607 iters/sec. Estimated time to finish: 0:00:13.510328.
# validation [##############################################....] 93.02%
#         40 iterations
#    0.28983 iters/sec. Estimated time to finish: 0:00:10.350952.
# validation [###############################################...] 95.35%
#         41 iterations
#    0.29606 iters/sec. Estimated time to finish: 0:00:06.755384.
# validation [################################################..] 97.67%
#         42 iterations
#    0.29723 iters/sec. Estimated time to finish: 0:00:03.364438.
# 44          15048       9.54915e-05  0.00271433  0.0111243   31277
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [#.................................................]  2.33%
#          1 iterations
#     2.1261 iters/sec. Estimated time to finish: 0:00:19.754501.
# validation [##................................................]  4.65%
#          2 iterations
#    0.24107 iters/sec. Estimated time to finish: 0:02:50.072492.
# validation [###...............................................]  6.98%
#          3 iterations
#    0.34228 iters/sec. Estimated time to finish: 0:01:56.862822.
# validation [####..............................................]  9.30%
#          4 iterations
#    0.23438 iters/sec. Estimated time to finish: 0:02:46.399328.
# validation [#####.............................................] 11.63%
#          5 iterations
#    0.28496 iters/sec. Estimated time to finish: 0:02:13.350839.
# validation [######............................................] 13.95%
#          6 iterations
#    0.23682 iters/sec. Estimated time to finish: 0:02:36.239619.
# validation [########..........................................] 16.28%
#          7 iterations
#    0.27126 iters/sec. Estimated time to finish: 0:02:12.713119.
# validation [#########.........................................] 18.60%
#          8 iterations
#    0.23048 iters/sec. Estimated time to finish: 0:02:31.853754.
# validation [##########........................................] 20.93%
#          9 iterations
#    0.25571 iters/sec. Estimated time to finish: 0:02:12.962687.
# validation [###########.......................................] 23.26%
#         10 iterations
#    0.23657 iters/sec. Estimated time to finish: 0:02:19.491539.
# validation [############......................................] 25.58%
#         11 iterations
#    0.25736 iters/sec. Estimated time to finish: 0:02:04.337993.
# validation [#############.....................................] 27.91%
#         12 iterations
#    0.23676 iters/sec. Estimated time to finish: 0:02:10.936013.
# validation [###############...................................] 30.23%
#         13 iterations
#    0.25413 iters/sec. Estimated time to finish: 0:01:58.051460.
# validation [################..................................] 32.56%
#         14 iterations
#    0.23927 iters/sec. Estimated time to finish: 0:02:01.202958.
# validation [#################.................................] 34.88%
#         15 iterations
#     0.2543 iters/sec. Estimated time to finish: 0:01:50.104402.
# validation [##################................................] 37.21%
#         16 iterations
#    0.24071 iters/sec. Estimated time to finish: 0:01:52.168842.
# validation [###################...............................] 39.53%
#         17 iterations
#    0.25396 iters/sec. Estimated time to finish: 0:01:42.378882.
# validation [####################..............................] 41.86%
#         18 iterations
#    0.24523 iters/sec. Estimated time to finish: 0:01:41.944052.
# validation [######################............................] 44.19%
#         19 iterations
#    0.25719 iters/sec. Estimated time to finish: 0:01:33.314596.
# validation [#######################...........................] 46.51%
#         20 iterations
#     0.2462 iters/sec. Estimated time to finish: 0:01:33.421802.
# validation [########################..........................] 48.84%
#         21 iterations
#    0.25702 iters/sec. Estimated time to finish: 0:01:25.596919.
# validation [#########################.........................] 51.16%
#         22 iterations
#    0.24788 iters/sec. Estimated time to finish: 0:01:24.716948.
# validation [##########################........................] 53.49%
#         23 iterations
#    0.25778 iters/sec. Estimated time to finish: 0:01:17.584821.
# validation [###########################.......................] 55.81%
#         24 iterations
#    0.24803 iters/sec. Estimated time to finish: 0:01:16.602943.
# validation [#############################.....................] 58.14%
#         25 iterations
#    0.25712 iters/sec. Estimated time to finish: 0:01:10.005013.
# validation [##############################....................] 60.47%
#         26 iterations
#    0.24808 iters/sec. Estimated time to finish: 0:01:08.525011.
# validation [###############################...................] 62.79%
#         27 iterations
#    0.25648 iters/sec. Estimated time to finish: 0:01:02.383536.
# validation [################################..................] 65.12%
#         28 iterations
#    0.24809 iters/sec. Estimated time to finish: 0:01:00.462471.
# validation [#################################.................] 67.44%
#         29 iterations
#    0.25588 iters/sec. Estimated time to finish: 0:00:54.712239.
# validation [##################################................] 69.77%
#         30 iterations
#    0.24524 iters/sec. Estimated time to finish: 0:00:53.009405.
# validation [####################################..............] 72.09%
#         31 iterations
#    0.25245 iters/sec. Estimated time to finish: 0:00:47.534615.
# validation [#####################################.............] 74.42%
#         32 iterations
#    0.24306 iters/sec. Estimated time to finish: 0:00:45.256424.
# validation [######################################............] 76.74%
#         33 iterations
#    0.24976 iters/sec. Estimated time to finish: 0:00:40.037704.
# validation [#######################################...........] 79.07%
#         34 iterations
#    0.24022 iters/sec. Estimated time to finish: 0:00:37.465681.
# validation [########################################..........] 81.40%
#         35 iterations
#    0.24646 iters/sec. Estimated time to finish: 0:00:32.459012.
# validation [#########################################.........] 83.72%
#         36 iterations
#    0.24194 iters/sec. Estimated time to finish: 0:00:28.932379.
# validation [###########################################.......] 86.05%
#         37 iterations
#    0.24788 iters/sec. Estimated time to finish: 0:00:24.205170.
# validation [############################################......] 88.37%
#         38 iterations
#    0.24045 iters/sec. Estimated time to finish: 0:00:20.793962.
# validation [#############################################.....] 90.70%
#         39 iterations
#    0.24605 iters/sec. Estimated time to finish: 0:00:16.256742.
# validation [##############################################....] 93.02%
#         40 iterations
#    0.24126 iters/sec. Estimated time to finish: 0:00:12.434784.
# validation [###############################################...] 95.35%
#         41 iterations
#    0.24657 iters/sec. Estimated time to finish: 0:00:08.111374.
# validation [################################################..] 97.67%
#         42 iterations
#     0.2468 iters/sec. Estimated time to finish: 0:00:04.051943.
# 45          15390       0           0.00275444  0.0115916   32172.5

# %%
del train_loader
del val_loader
del model
del optimizer
del scheduler
del loss_func
del manager
gc.collect()
# Out:
# 251298

# %% [markdown]
# ## save results

# %%
# %%bash
# ls /kaggle/training_output
# Out:
# log
# loss.png
# lr.png
# snapshot_epoch_1.pth
# snapshot_epoch_12.pth
# snapshot_epoch_14.pth
# snapshot_epoch_15.pth
# snapshot_epoch_17.pth
# snapshot_epoch_18.pth
# snapshot_epoch_19.pth
# snapshot_epoch_2.pth
# snapshot_epoch_3.pth
# snapshot_epoch_4.pth
# snapshot_epoch_5.pth
# snapshot_epoch_6.pth
# snapshot_epoch_7.pth
# snapshot_epoch_8.pth
# snapshot_epoch_9.pth

# %%
for f_name in ["log","loss.png", "lr.png"]:
    shutil.copy(output_dir / f_name, f_name)

# %%
log = pd.read_json("log")
best_epoch = log["val/loss"].idxmin() + 1
log.iloc[[best_epoch - 1],]
# Out:
#     train/loss        lr  val/loss  epoch  iteration  elapsed_time
# 18    0.006613  0.000905  0.009921     19       6498  13131.989599

# %%
shutil.copy(output_dir / "snapshot_epoch_{}.pth".format(best_epoch), "best_model.pth")
# Out:
# 'best_model.pth'

# %%
m = get_model({
    'name': settings["model"]["name"],
    'params': {'pretrained': False, 'n_classes': 264}})
state_dict = torch.load('best_model.pth')
m.load_state_dict(state_dict)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-f322e41478b6> in <module>
#       1 m = get_model({
# ----> 2     'name': settings["model"]["name"],
#       3     'params': {'pretrained': False, 'n_classes': 264}})
#       4 state_dict = torch.load('best_model.pth')
#       5 m.load_state_dict(state_dict)
#
# KeyError: 'name'
